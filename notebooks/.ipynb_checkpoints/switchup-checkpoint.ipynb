# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 5-6 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
import re
import numpy as np
import pandas as pd
from pandas import json_normalize
import requests
from bs4 import BeautifulSoup
import json
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import getpass
import mysql.connector

# %% [markdown]
# The dictionary schools needs to be expanded to include all the schools for which you want to scrape reviews.
#
# The current implementation fetches reviews from a specific page (page=3). This may need to be adjusted depending on your requirements.
#
# The perPage=10000 parameter suggests the script is attempting to fetch a large number of reviews at once, which might need to be modified based on API limitations or performance considerations.

# %% [markdown]
# # Retrive Ranking for Data Analytics, Coding, Cyber Security and Web Design Bootcamps

# %%
def get_bootcamp_rankings(url, course):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, "html.parser")
        
        # Extracting date updated
        date_updated_element = soup.find("div", class_="date-updated")
        date_updated_str = date_updated_element.text.strip() if date_updated_element else None
        
         # Convert the date string into a datetime object
        date_updated = datetime.strptime(date_updated_str, "Last Updated: %B %d, %Y") if date_updated_str else None
        
        # Find the bootcamp list
        bootcamp_list = soup.find("bootcamp-list")
        
        if bootcamp_list:
            # Extract JSON data
            json_data = bootcamp_list.find("script", type="application/ld+json").string
            
            # Parse JSON data
            data = json.loads(json_data)
            
            # Extract bootcamp rankings, names, and URLs
            rankings = []
            for item in data.get("itemListElement", []):
                if "item" in item:
                    position = item.get("position", "")
                    name = item["item"].get("name", "")
                    ranking_dict = {"ranking": position, "bootcamp_name": name, "course": course}
                    
                    rankings.append(ranking_dict)
    
            # Create DataFrame
            bootcamp_data = pd.DataFrame(rankings)
            
            # Add Date Updated column
            bootcamp_data["date_updated"] = date_updated
            
            return bootcamp_data
        else:
            print(f"Failed to find bootcamp list on {url}")
            return None
    else:
        print(f"Failed to retrieve the page {url}. Status code: {response.status_code}")
        return None

# URLs for different courses
urls = {
    "Data Analytics": "https://www.switchup.org/rankings/best-data-analytics-bootcamps",
    "Coding": "https://www.switchup.org/rankings/best-coding-bootcamps",
    "Cyber Security": "https://www.switchup.org/rankings/best-cyber-security-bootcamps",
    "Web Design": "https://www.switchup.org/rankings/best-web-design-bootcamps"
}

# Empty DataFrame to store results
all_bootcamp_data = pd.DataFrame()

# Iterate through each course URL
for course, url in urls.items():
    bootcamp_data = get_bootcamp_rankings(url, course)
    if bootcamp_data is not None:
        all_bootcamp_data = pd.concat([all_bootcamp_data, bootcamp_data], ignore_index=True)

# Display the combined DataFrame
display(all_bootcamp_data)
# Out:
#     ranking                                      bootcamp_name  \
# 0         1                                        Springboard
# 1         2                                          Dataquest
# 2         3                                Syntax Technologies
# 3         4                                           Ironhack
# 4         5                                          TripleTen
# 5         6                                          Colaberry
# 6         7                                    Maven Analytics
# 7         8                                            Udacity
# 8         9                                       BrainStation
# 9        10                               CCS Learning Academy
# 10       11                                           Thinkful
# 11       12                                   General Assembly
# 12        1                                          Actualize
# 13        2                                       LearningFuze
# 14        3                                          Clarusway
# 15        4                                        Springboard
# 16        5                                          Codesmith
# 17        6                                       Code Platoon
# 18        7                                       KnowledgeHut
# 19        8                                            Udacity
# 20        9                                          Altcademy
# 21       10                                      Tech Elevator
# 22       11                                          Codeworks
# 23       12                                     4Geeks Academy
# 24       13                                      Coding Temple
# 25       14                                        devCodeCamp
# 26       15                                             Nucamp
# 27       16                                          TripleTen
# 28       17                                           Ironhack
# 29       18                                         Skillcrush
# 30       19                                   The Tech Academy
# 31       20                                       Hack Reactor
# 32       21                                          TECH I.S.
# 33       22                                        App Academy
# 34       23                                       BrainStation
# 35       24                                        Coding Dojo
# 36        1                            Evolve Security Academy
# 37        2                                Syntax Technologies
# 38        3                                       Level Effect
# 39        4                                          Clarusway
# 40        5                                        Simplilearn
# 41        6                                        Springboard
# 42        7                                            Edureka
# 43        8  Colorado State University Pueblo Extended Studies
# 44        1                                          Designlab
# 45        2                                        Springboard
# 46        3                                           Ironhack
# 47        4                                UX Design Institute
# 48        5                               Mento Design Academy
# 49        6                                            Beginex
# 50        7                                            Udacity
# 51        8                                       BrainStation
# 52        9                               Design Sprint School
# 53       10                                   General Assembly
#
#             course date_updated
# 0   Data Analytics   2023-04-25
# 1   Data Analytics   2023-04-25
# 2   Data Analytics   2023-04-25
# 3   Data Analytics   2023-04-25
# 4   Data Analytics   2023-04-25
# 5   Data Analytics   2023-04-25
# 6   Data Analytics   2023-04-25
# 7   Data Analytics   2023-04-25
# 8   Data Analytics   2023-04-25
# 9   Data Analytics   2023-04-25
# 10  Data Analytics   2023-04-25
# 11  Data Analytics   2023-04-25
# 12          Coding   2023-04-25
# 13          Coding   2023-04-25
# 14          Coding   2023-04-25
# 15          Coding   2023-04-25
# 16          Coding   2023-04-25
# 17          Coding   2023-04-25
# 18          Coding   2023-04-25
# 19          Coding   2023-04-25
# 20          Coding   2023-04-25
# 21          Coding   2023-04-25
# 22          Coding   2023-04-25
# 23          Coding   2023-04-25
# 24          Coding   2023-04-25
# 25          Coding   2023-04-25
# 26          Coding   2023-04-25
# 27          Coding   2023-04-25
# 28          Coding   2023-04-25
# 29          Coding   2023-04-25
# 30          Coding   2023-04-25
# 31          Coding   2023-04-25
# 32          Coding   2023-04-25
# 33          Coding   2023-04-25
# 34          Coding   2023-04-25
# 35          Coding   2023-04-25
# 36  Cyber Security   2023-04-25
# 37  Cyber Security   2023-04-25
# 38  Cyber Security   2023-04-25
# 39  Cyber Security   2023-04-25
# 40  Cyber Security   2023-04-25
# 41  Cyber Security   2023-04-25
# 42  Cyber Security   2023-04-25
# 43  Cyber Security   2023-04-25
# 44      Web Design   2023-04-25
# 45      Web Design   2023-04-25
# 46      Web Design   2023-04-25
# 47      Web Design   2023-04-25
# 48      Web Design   2023-04-25
# 49      Web Design   2023-04-25
# 50      Web Design   2023-04-25
# 51      Web Design   2023-04-25
# 52      Web Design   2023-04-25
# 53      Web Design   2023-04-25

# %%
# Remove hours, minutes, and seconds from 'Date Updated' that appears on MySQL
all_bootcamp_data['date_updated'] = all_bootcamp_data['date_updated'].dt.date

# %%
all_bootcamp_data.dtypes
# Out:
# ranking           int64
# bootcamp_name    object
# course           object
# date_updated     object
# dtype: object

# %% [markdown]
# # Position of Ironhack in each Course

# %%
# Get unique courses
unique_courses = all_bootcamp_data['course'].unique()

# Iterate through unique courses
for course in unique_courses:
    print(f"Course: {course}")
    
    # Check if Ironhack is listed for the current course
    ironhack_data = all_bootcamp_data[(all_bootcamp_data['course'] == course) & 
                                      (all_bootcamp_data['bootcamp_name'] == 'Ironhack')]
    
    if not ironhack_data.empty:
        ranking = ironhack_data.iloc[0]['ranking']
        print(f"Ironhack is the ranking for {course} in position {ranking}.")
    else:
        print(f"Ironhack is not in the ranking for {course}.")

    print()
# Out:
# Course: Data Analytics
# Ironhack is the ranking for Data Analytics in position 4.
#
# Course: Coding
# Ironhack is the ranking for Coding in position 17.
#
# Course: Cyber Security
# Ironhack is not in the ranking for Cyber Security.
#
# Course: Web Design
# Ironhack is the ranking for Web Design in position 3.

# %% [markdown]
# # Best cybersecurity bootcamps

# %%
# Create a list of best cybersecurity bootcamps
#cybersecurity_bootcamps = all_bootcamp_data[all_bootcamp_data['Course'] == 'Cyber Security']['Bootcamp Name'].tolist()

# Add Ironhack to compara the best ones with Ironhack
#cybersecurity_bootcamps.append('Ironhack')
#cybersecurity_bootcamps

# %%
CS_Schools = {   
'Evolve Security Academy' : 10743,
'Syntax Technologies' : 11797, 
'Level Effect' : 11282,
'Clarusway': 11539,
'Simplilearn': 11016,
'Springboard' : 11035,
'Edureka': 11739,
'Colorado State University Pueblo Extended Studies': 11296,
'Ironhack' : 10828}

# %%
# Filter the DataFrame for the Cyber Security course
cyber_security_data = all_bootcamp_data[all_bootcamp_data['course'] == 'Cyber Security'].copy()

# Map bootcamp names to their corresponding IDs
cyber_security_data['bootcamp_id'] = cyber_security_data['bootcamp_name'].map(CS_Schools)

cyber_security_data.reset_index(drop=True, inplace=True)
cyber_security_data
# Out:
#    ranking                                      bootcamp_name          course  \
# 0        1                            Evolve Security Academy  Cyber Security
# 1        2                                Syntax Technologies  Cyber Security
# 2        3                                       Level Effect  Cyber Security
# 3        4                                          Clarusway  Cyber Security
# 4        5                                        Simplilearn  Cyber Security
# 5        6                                        Springboard  Cyber Security
# 6        7                                            Edureka  Cyber Security
# 7        8  Colorado State University Pueblo Extended Studies  Cyber Security
#
#   date_updated  bootcamp_id
# 0   2023-04-25        10743
# 1   2023-04-25        11797
# 2   2023-04-25        11282
# 3   2023-04-25        11539
# 4   2023-04-25        11016
# 5   2023-04-25        11035
# 6   2023-04-25        11739
# 7   2023-04-25        11296

# %%
cyber_security_data.dtypes
# Out:
# ranking           int64
# bootcamp_name    object
# course           object
# date_updated     object
# bootcamp_id       int64
# dtype: object

# %% [markdown]
# # Conditions to be considered best bootcamp
# - Have at least one U.S. campus OR be U.S.-based if they're an online-only program
# - Have at least 10 verified reviews since 2019
# - Average reviews at least four out of five stars

# %%
#CS_bootcamp_html_name
schools = {
'evolve-security-academy' : 10743,
'syntax-technologies' : 11797, 
'level-effect' : 11282,
'clarusway': 11539,
'simplilearn': 11016,
'springboard' : 11035,
'edureka': 11739,
'colorado-state-university-pueblo-extended-studies': 11296,
'ironhack' : 10828}

# %%
def get_comments_school(school, bootcamp_id):
    TAG_RE = re.compile(r'<[^>]+>')
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    data = requests.get(url).json()
    reviews = pd.DataFrame(data['content']['reviews'])

    def remove_tags(x):
        return TAG_RE.sub('', x)

    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    reviews['bootcamp_id'] = bootcamp_id
    return reviews
    return reviews

# %% [markdown]
# ## Reviews

# %%
comments = pd.concat([get_comments_school(school, bootcamp_id) for school, bootcamp_id in schools.items()])
display(comments)
# Out:
#           id                   name  anonymous hostProgramName  \
# 0     310012      Yolanda Mondragon      False            None
# 1     309927      MINH CUONG NGUYEN      False            None
# 2     308332             Michelle H      False            None
# 3     308033    Sandrine Mamigonian      False            None
# 4     307829            kacy yancey      False            None
# ...      ...                    ...        ...             ...
# 1288  231772              Anonymous      False            None
# 1289  231636        Marcos Sorribas      False            None
# 1290  231611          Xabier Vicuña      False            None
# 1291  231609                    JHD      False            None
# 1292  231815  Enrique Isasi Velasco      False    UX/UI Design
#
#       graduatingYear  isAlumni                                 jobTitle  \
# 0             2024.0     False
# 1             2024.0     False                            IT Technician
# 2             2023.0     False
# 3             2023.0     False
# 4             2023.0     False                                  student
# ...              ...       ...                                      ...
# 1288          2014.0      True                                     None
# 1289          2014.0      True                            iOS Developer
# 1290          2014.0      True                             Entrepreneur
# 1291          2014.0      True                                     None
# 1292          2014.0      True  Founder, RoR Developer @ Decorissimo.es
#
#                                                 tagline  \
# 0                  Exceptional instructors and support!
# 1                  Evolve Academy: OSCP Bootcamp Review
# 2                         Wonderful Learning Experience
# 3           Graphic Design to Cyber Security Transition
# 4                                        great program!
# ...                                                 ...
# 1288  Learn in two months what would otherwise take ...
# 1289  El mejor bootcamp al que he asistido. Una expe...
# 1290            Great experience, I highly recommend it
# 1291                      It was an amazing experience!
# 1292                                   Simply gorgeous.
#
#                                                    body  \
# 0     <span class="truncatable"><p></p><p>I'm so gla...
# 1     <span class="truncatable"><p></p><p>Pros: The ...
# 2     <span class="truncatable"><p></p><p>The Evolve...
# 3     <span class="truncatable"><p></p><p>I recently...
# 4     <span class="truncatable"><p></p><p>After thor...
# ...                                                 ...
# 1288  <span class="truncatable"><p>I can fully recom...
# 1289  <span class="truncatable"><p>Asistí al primer ...
# 1290  <span class="truncatable"><p>Excellent product...
# 1291  <span class="truncatable"><p>I was part of the...
# 1292  <span class="truncatable"><p>I attended the Ir...
#
#                                                 rawBody  ...  \
# 0     <p>I&#39;m so glad I found the Evolve Security...  ...
# 1     <p>Pros: The course was amazing, it created a ...  ...
# 2     <p>The Evolve Academy bootcamp is a good entry...  ...
# 3     <p>I recently transitioned from graphic design...  ...
# 4     <p>After thorough bootcamp research, I confide...  ...
# ...                                                 ...  ...
# 1288  I can fully recommend IronHack for any of you ...  ...
# 1289  Asistí al primer bootcamp de desarrollo de iOS...  ...
# 1290  Excellent product. Great experience. Worth eve...  ...
# 1291  I was part of the first English run of Ironhac...  ...
# 1292  I attended the Ironhack Madrid Bootcamp on Jan...  ...
#
#                                            program             user  \
# 0     Cybersecurity Bootcamp: REMOTE (Live-Online)  {'image': None}
# 1                                             None  {'image': None}
# 2     Cybersecurity Bootcamp: REMOTE (Live-Online)  {'image': None}
# 3     Cybersecurity Bootcamp: REMOTE (Live-Online)  {'image': None}
# 4                           Cybersecurity Bootcamp  {'image': None}
# ...                                            ...              ...
# 1288                     Part-time Web Development  {'image': None}
# 1289           Full-time Web Development Bootcamp   {'image': None}
# 1290                     Part-time Web Development  {'image': None}
# 1291                     Part-time Web Development  {'image': None}
# 1292                     Part-time Web Development  {'image': None}
#
#      overallScore                                           comments overall  \
# 0             5.0  [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0
# 1             4.0  [{'name': 'Colleen', 'email': 'cbradley@evolve...     4.0
# 2             5.0  [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0
# 3             5.0  [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0
# 4             5.0  [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0
# ...           ...                                                ...     ...
# 1288          5.0                                                 []     5.0
# 1289          5.0                                                 []     5.0
# 1290          5.0                                                 []     5.0
# 1291          5.0                                                 []     5.0
# 1292          5.0                                                 []     5.0
#
#      curriculum jobSupport                                        review_body  \
# 0           5.0        5.0  I'm so glad I found the Evolve Security Academ...
# 1           4.0        4.0  Pros: The course was amazing, it created a sol...
# 2           5.0        5.0  The Evolve Academy bootcamp is a good entry fo...
# 3           5.0        5.0  I recently transitioned from graphic design to...
# 4           5.0        5.0  After thorough bootcamp research, I confidentl...
# ...         ...        ...                                                ...
# 1288        5.0        5.0  I can fully recommend IronHack for any of you ...
# 1289        5.0        5.0  Asistí al primer bootcamp de desarrollo de iOS...
# 1290        5.0        5.0  Excellent product. Great experience. Worth eve...
# 1291        5.0        5.0  I was part of the first English run of Ironhac...
# 1292        5.0        5.0  I attended the Ironhack Madrid Bootcamp on Jan...
#
#                        school bootcamp_id
# 0     evolve-security-academy       10743
# 1     evolve-security-academy       10743
# 2     evolve-security-academy       10743
# 3     evolve-security-academy       10743
# 4     evolve-security-academy       10743
# ...                       ...         ...
# 1288                 ironhack       10828
# 1289                 ironhack       10828
# 1290                 ironhack       10828
# 1291                 ironhack       10828
# 1292                 ironhack       10828
#
# [4532 rows x 22 columns]

# %%
# Replace None values with 'Unknown'
comments.fillna('Unknown', inplace=True)

display(comments)
# Out:
# /var/folders/k5/l8tkch0x0538653kdhf3q9p00000gn/T/ipykernel_43504/2945652732.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   comments.fillna('Unknown', inplace=True)
#           id                   name  anonymous hostProgramName graduatingYear  \
# 0     310012      Yolanda Mondragon      False         Unknown         2024.0
# 1     309927      MINH CUONG NGUYEN      False         Unknown         2024.0
# 2     308332             Michelle H      False         Unknown         2023.0
# 3     308033    Sandrine Mamigonian      False         Unknown         2023.0
# 4     307829            kacy yancey      False         Unknown         2023.0
# ...      ...                    ...        ...             ...            ...
# 1288  231772              Anonymous      False         Unknown         2014.0
# 1289  231636        Marcos Sorribas      False         Unknown         2014.0
# 1290  231611          Xabier Vicuña      False         Unknown         2014.0
# 1291  231609                    JHD      False         Unknown         2014.0
# 1292  231815  Enrique Isasi Velasco      False    UX/UI Design         2014.0
#
#       isAlumni                                 jobTitle  \
# 0        False
# 1        False                            IT Technician
# 2        False
# 3        False
# 4        False                                  student
# ...        ...                                      ...
# 1288      True                                  Unknown
# 1289      True                            iOS Developer
# 1290      True                             Entrepreneur
# 1291      True                                  Unknown
# 1292      True  Founder, RoR Developer @ Decorissimo.es
#
#                                                 tagline  \
# 0                  Exceptional instructors and support!
# 1                  Evolve Academy: OSCP Bootcamp Review
# 2                         Wonderful Learning Experience
# 3           Graphic Design to Cyber Security Transition
# 4                                        great program!
# ...                                                 ...
# 1288  Learn in two months what would otherwise take ...
# 1289  El mejor bootcamp al que he asistido. Una expe...
# 1290            Great experience, I highly recommend it
# 1291                      It was an amazing experience!
# 1292                                   Simply gorgeous.
#
#                                                    body  \
# 0     <span class="truncatable"><p></p><p>I'm so gla...
# 1     <span class="truncatable"><p></p><p>Pros: The ...
# 2     <span class="truncatable"><p></p><p>The Evolve...
# 3     <span class="truncatable"><p></p><p>I recently...
# 4     <span class="truncatable"><p></p><p>After thor...
# ...                                                 ...
# 1288  <span class="truncatable"><p>I can fully recom...
# 1289  <span class="truncatable"><p>Asistí al primer ...
# 1290  <span class="truncatable"><p>Excellent product...
# 1291  <span class="truncatable"><p>I was part of the...
# 1292  <span class="truncatable"><p>I attended the Ir...
#
#                                                 rawBody  ...  \
# 0     <p>I&#39;m so glad I found the Evolve Security...  ...
# 1     <p>Pros: The course was amazing, it created a ...  ...
# 2     <p>The Evolve Academy bootcamp is a good entry...  ...
# 3     <p>I recently transitioned from graphic design...  ...
# 4     <p>After thorough bootcamp research, I confide...  ...
# ...                                                 ...  ...
# 1288  I can fully recommend IronHack for any of you ...  ...
# 1289  Asistí al primer bootcamp de desarrollo de iOS...  ...
# 1290  Excellent product. Great experience. Worth eve...  ...
# 1291  I was part of the first English run of Ironhac...  ...
# 1292  I attended the Ironhack Madrid Bootcamp on Jan...  ...
#
#                                            program             user  \
# 0     Cybersecurity Bootcamp: REMOTE (Live-Online)  {'image': None}
# 1                                          Unknown  {'image': None}
# 2     Cybersecurity Bootcamp: REMOTE (Live-Online)  {'image': None}
# 3     Cybersecurity Bootcamp: REMOTE (Live-Online)  {'image': None}
# 4                           Cybersecurity Bootcamp  {'image': None}
# ...                                            ...              ...
# 1288                     Part-time Web Development  {'image': None}
# 1289           Full-time Web Development Bootcamp   {'image': None}
# 1290                     Part-time Web Development  {'image': None}
# 1291                     Part-time Web Development  {'image': None}
# 1292                     Part-time Web Development  {'image': None}
#
#      overallScore                                           comments overall  \
# 0             5.0  [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0
# 1             4.0  [{'name': 'Colleen', 'email': 'cbradley@evolve...     4.0
# 2             5.0  [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0
# 3             5.0  [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0
# 4             5.0  [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0
# ...           ...                                                ...     ...
# 1288          5.0                                                 []     5.0
# 1289          5.0                                                 []     5.0
# 1290          5.0                                                 []     5.0
# 1291          5.0                                                 []     5.0
# 1292          5.0                                                 []     5.0
#
#      curriculum jobSupport                                        review_body  \
# 0           5.0        5.0  I'm so glad I found the Evolve Security Academ...
# 1           4.0        4.0  Pros: The course was amazing, it created a sol...
# 2           5.0        5.0  The Evolve Academy bootcamp is a good entry fo...
# 3           5.0        5.0  I recently transitioned from graphic design to...
# 4           5.0        5.0  After thorough bootcamp research, I confidentl...
# ...         ...        ...                                                ...
# 1288        5.0        5.0  I can fully recommend IronHack for any of you ...
# 1289        5.0        5.0  Asistí al primer bootcamp de desarrollo de iOS...
# 1290        5.0        5.0  Excellent product. Great experience. Worth eve...
# 1291        5.0        5.0  I was part of the first English run of Ironhac...
# 1292        5.0        5.0  I attended the Ironhack Madrid Bootcamp on Jan...
#
#                        school bootcamp_id
# 0     evolve-security-academy       10743
# 1     evolve-security-academy       10743
# 2     evolve-security-academy       10743
# 3     evolve-security-academy       10743
# 4     evolve-security-academy       10743
# ...                       ...         ...
# 1288                 ironhack       10828
# 1289                 ironhack       10828
# 1290                 ironhack       10828
# 1291                 ironhack       10828
# 1292                 ironhack       10828
#
# [4532 rows x 22 columns]

# %%
comments.columns
# Out:
# Index(['id', 'name', 'anonymous', 'hostProgramName', 'graduatingYear',
#        'isAlumni', 'jobTitle', 'tagline', 'body', 'rawBody', 'createdAt',
#        'queryDate', 'program', 'user', 'overallScore', 'comments', 'overall',
#        'curriculum', 'jobSupport', 'review_body', 'school', 'bootcamp_id'],
#       dtype='object')

# %%
comments.dtypes
# Out:
# id                  int64
# name               object
# anonymous            bool
# hostProgramName    object
# graduatingYear     object
# isAlumni             bool
# jobTitle           object
# tagline            object
# body               object
# rawBody            object
# createdAt          object
# queryDate          object
# program            object
# user               object
# overallScore       object
# comments           object
# overall            object
# curriculum         object
# jobSupport         object
# review_body        object
# school             object
# bootcamp_id         int64
# dtype: object

# %%
#Change data types

comments['id']=comments['id'].astype('Int64')
comments['graduatingYear'] = pd.to_numeric(comments['graduatingYear'], errors='coerce').astype('Int64')
comments['createdAt'] = pd.to_datetime(comments['createdAt'])
comments['queryDate'] = pd.to_datetime(comments['queryDate'])
comments['overallScore'] = pd.to_numeric(comments['overallScore'], errors='coerce')
comments['curriculum'] = pd.to_numeric(comments['curriculum'], errors='coerce')
comments['jobSupport'] = pd.to_numeric(comments['jobSupport'], errors='coerce')
comments.dtypes
# Out:
# id                          Int64
# name                       object
# anonymous                    bool
# hostProgramName            object
# graduatingYear              Int64
# isAlumni                     bool
# jobTitle                   object
# tagline                    object
# body                       object
# rawBody                    object
# createdAt          datetime64[ns]
# queryDate          datetime64[ns]
# program                    object
# user                       object
# overallScore              float64
# comments                   object
# overall                    object
# curriculum                float64
# jobSupport                float64
# review_body                object
# school                     object
# bootcamp_id                 int64
# dtype: object

# %%
comments.head(3)
# Out:
#        id               name  anonymous hostProgramName  graduatingYear  \
# 0  310012  Yolanda Mondragon      False         Unknown            2024
# 1  309927  MINH CUONG NGUYEN      False         Unknown            2024
# 2  308332         Michelle H      False         Unknown            2023
#
#    isAlumni       jobTitle                               tagline  \
# 0     False                 Exceptional instructors and support!
# 1     False  IT Technician  Evolve Academy: OSCP Bootcamp Review
# 2     False                        Wonderful Learning Experience
#
#                                                 body  \
# 0  <span class="truncatable"><p></p><p>I'm so gla...
# 1  <span class="truncatable"><p></p><p>Pros: The ...
# 2  <span class="truncatable"><p></p><p>The Evolve...
#
#                                              rawBody  ...  \
# 0  <p>I&#39;m so glad I found the Evolve Security...  ...
# 1  <p>Pros: The course was amazing, it created a ...  ...
# 2  <p>The Evolve Academy bootcamp is a good entry...  ...
#
#                                         program             user overallScore  \
# 0  Cybersecurity Bootcamp: REMOTE (Live-Online)  {'image': None}          5.0
# 1                                       Unknown  {'image': None}          4.0
# 2  Cybersecurity Bootcamp: REMOTE (Live-Online)  {'image': None}          5.0
#
#                                             comments  overall curriculum  \
# 0  [{'name': 'Colleen', 'email': 'cbradley@evolve...      5.0        5.0
# 1  [{'name': 'Colleen', 'email': 'cbradley@evolve...      4.0        4.0
# 2  [{'name': 'Colleen', 'email': 'cbradley@evolve...      5.0        5.0
#
#   jobSupport                                        review_body  \
# 0        5.0  I'm so glad I found the Evolve Security Academ...
# 1        4.0  Pros: The course was amazing, it created a sol...
# 2        5.0  The Evolve Academy bootcamp is a good entry fo...
#
#                     school bootcamp_id
# 0  evolve-security-academy       10743
# 1  evolve-security-academy       10743
# 2  evolve-security-academy       10743
#
# [3 rows x 22 columns]

# %%
comments.columns
# Out:
# Index(['id', 'name', 'anonymous', 'hostProgramName', 'graduatingYear',
#        'isAlumni', 'jobTitle', 'tagline', 'body', 'rawBody', 'createdAt',
#        'queryDate', 'program', 'user', 'overallScore', 'comments', 'overall',
#        'curriculum', 'jobSupport', 'review_body', 'school', 'bootcamp_id'],
#       dtype='object')

# %%
#Drop rows that are not needed
columns_to_drop=['anonymous', 'isAlumni', 'tagline', 'body', 'rawBody', 'user','graduatingYear','jobTitle']
comments = comments.drop(columns=columns_to_drop, axis=1)

# %%
comments.columns
# Out:
# Index(['id', 'name', 'hostProgramName', 'createdAt', 'queryDate', 'program',
#        'overallScore', 'comments', 'overall', 'curriculum', 'jobSupport',
#        'review_body', 'school', 'bootcamp_id'],
#       dtype='object')

# %%
comments.dtypes
# Out:
# id                          Int64
# name                       object
# hostProgramName            object
# createdAt          datetime64[ns]
# queryDate          datetime64[ns]
# program                    object
# overallScore              float64
# comments                   object
# overall                    object
# curriculum                float64
# jobSupport                float64
# review_body                object
# school                     object
# bootcamp_id                 int64
# dtype: object

# %%
#Number of programs per school
programs_per_school = comments.groupby('school')['program'].nunique().reset_index()
programs_per_school.columns = ['school_name', 'number_of_programs']
programs_per_school.sort_values(by='number_of_programs', ascending=False).reset_index()
display(programs_per_school)
# Out:
#                                          school_name  number_of_programs
# 0                                          clarusway                  32
# 1  colorado-state-university-pueblo-extended-studies                   2
# 2                                            edureka                  23
# 3                            evolve-security-academy                  11
# 4                                           ironhack                  17
# 5                                       level-effect                   2
# 6                                        simplilearn                  42
# 7                                        springboard                  25
# 8                                syntax-technologies                   3

# %%
#Number of reviews per school
reviews_per_school = comments['school'].value_counts()
display(reviews_per_school)
# Out:
# school
# springboard                                          1658
# ironhack                                             1293
# edureka                                               530
# simplilearn                                           445
# clarusway                                             243
# evolve-security-academy                               229
# syntax-technologies                                   103
# level-effect                                           21
# colorado-state-university-pueblo-extended-studies      10
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
reviews_per_school.plot(kind='bar', color='skyblue')
plt.xlabel('School')
plt.ylabel('Number of Reviews')
plt.title('Number of Reviews per School')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()

# %% [markdown]
# ### We already know that Cybersecurity is not in the ranking

# %%
#Programs in ironhack
#Let's confirm the program with lowest ranking
ironhack= comments[(comments['school']=='ironhack')]
scores=ironhack.groupby(['program','school']).agg({'overallScore': 'mean'})
scores.sort_values(by='overallScore', ascending=True).reset_index()

#There are programs that are not filled but hostProgramName is always filled
# Out:
#                                 program    school  overallScore
# 0               Cybersecurity Part-Time  ironhack      3.866667
# 1              Data Analytics Part-Time  ironhack      4.266667
# 2               Cyber Security Bootcamp  ironhack      4.283333
# 3               Data Analytics Bootcamp  ironhack      4.435593
# 4                 UX/UI Design Bootcamp  ironhack      4.512150
# 5                UX/UI Design Part-Time  ironhack      4.563636
# 6             Web Development Part-Time  ironhack      4.576000
# 7                               Unknown  ironhack      4.641379
# 8                                        ironhack      4.652542
# 9              Web Development Bootcamp  ironhack      4.654167
# 10      Full-time UX/UI Design Bootcamp  ironhack      4.778788
# 11               Part-time UX/UI Design  ironhack      4.800000
# 12   Full-time Web Development Bootcamp  ironhack      4.847059
# 13              Part-time UX/UI Design   ironhack      4.857143
# 14            Part-time Web Development  ironhack      4.891489
# 15  Full-time Web Development Bootcamp   ironhack      4.912707
# 16                           Web Design  ironhack      4.978571

# %%
#hostProgramName ranking for ironhack
ironhack= comments[(comments['school']=='ironhack')]
scores=ironhack.groupby(['hostProgramName','school']).agg({'overallScore': 'mean'})
scores.sort_values(by='overallScore', ascending=True).reset_index()
# Out:
#         hostProgramName    school  overallScore
# 0               Unknown  ironhack      4.580492
# 1          UX/UI Design  ironhack      4.753738
# 2        Data Analytics  ironhack      4.850000
# 3  Software Engineering  ironhack      4.896190
# 4       Web Development  ironhack      4.918182

# %%
# Does Software Engineering correspond to Cyber Security? NO
ironhack_software_engineering= comments[(comments['school']=='ironhack') & (comments['hostProgramName']=='Software Engineering')]
ironhack_software_engineering
# Out:
#           id                   name       hostProgramName  createdAt  \
# 344   267263              Anonymous  Software Engineering 2020-08-07
# 345   267141          Edgar Chavero  Software Engineering 2020-08-03
# 346   266915              Anonymous  Software Engineering 2020-07-29
# 348   266881              Anonymous  Software Engineering 2020-07-28
# 353   266425           Sofia Franek  Software Engineering 2020-07-15
# ...      ...                    ...                   ...        ...
# 1005  242140  Alberto Rivera Merida  Software Engineering 2018-02-06
# 1006  245052        Nikolaas Verlee  Software Engineering 2018-01-19
# 1007  241734  Jessica Alin González  Software Engineering 2018-01-16
# 1009  241667          Alber Pedraza  Software Engineering 2018-01-14
# 1015  240856                 Fran R  Software Engineering 2018-01-09
#
#       queryDate                              program  overallScore comments  \
# 344  2020-08-07                                                4.7       []
# 345  2020-08-03             Web Development Bootcamp           5.0       []
# 346  2020-07-29            Web Development Part-Time           4.7       []
# 348  2020-07-28            Web Development Part-Time           5.0       []
# 353  2020-07-15             Web Development Bootcamp           5.0       []
# ...         ...                                  ...           ...      ...
# 1005 2018-02-06  Full-time Web Development Bootcamp            5.0       []
# 1006 2018-01-19  Full-time Web Development Bootcamp            5.0       []
# 1007 2018-01-16  Full-time Web Development Bootcamp            5.0       []
# 1009 2018-01-14                              Unknown           5.0       []
# 1015 2018-01-09  Full-time Web Development Bootcamp            5.0       []
#
#      overall  curriculum  jobSupport  \
# 344      5.0         5.0         4.0
# 345      5.0         5.0         5.0
# 346      5.0         5.0         4.0
# 348      5.0         5.0         5.0
# 353      5.0         5.0         5.0
# ...      ...         ...         ...
# 1005     5.0         5.0         5.0
# 1006     5.0         5.0         5.0
# 1007     5.0         5.0         5.0
# 1009     5.0         5.0         5.0
# 1015     5.0         5.0         5.0
#
#                                             review_body    school  bootcamp_id
# 344   Los contras seria lo frustrado que te sientes ...  ironhack        10828
# 345   Great experience at Ironhack Mexico, the teach...  ironhack        10828
# 346   I just finished the Web Development part-time ...  ironhack        10828
# 348   I've just completed the Web Development part-t...  ironhack        10828
# 353   I attended Ironhack in Lisbon, January 2020. I...  ironhack        10828
# ...                                                 ...       ...          ...
# 1005  Ironhack es una experiencia que se comprime en...  ironhack        10828
# 1006  I had the chance to experience the full time I...  ironhack        10828
# 1007  WARNING: This is the longest review ever.  All...  ironhack        10828
# 1009  Un Bootcamp de lo más completo, que recomiendo...  ironhack        10828
# 1015  I think it is a great personal investment due ...  ironhack        10828
#
# [420 rows x 14 columns]

# %%
# Filter to have only cybersecurity programs
cyber_security_comments = comments[comments['program'].str.contains(r"Cyber\s?Security", case=False, na=False)]

display(cyber_security_comments)
# Out:
#          id                        name hostProgramName  createdAt  queryDate  \
# 0    310012           Yolanda Mondragon         Unknown 2024-04-10 2024-04-10
# 2    308332                  Michelle H         Unknown 2024-01-31 2024-01-31
# 3    308033         Sandrine Mamigonian         Unknown 2024-01-18 2024-01-18
# 4    307829                 kacy yancey         Unknown 2024-01-09 2024-01-09
# 5    307828            Spencer Shumpert         Unknown 2024-01-09 2024-01-09
# ..      ...                         ...             ...        ...        ...
# 100  295495      Kotryna Laurinaviciute         Unknown 2022-12-06 2022-12-06
# 125  294342  Juan Carlos Camós da Silva         Unknown 2022-10-27 2022-10-27
# 126  294211                   Anonymous         Unknown 2022-10-21 2022-10-21
# 135  293621                       Lluis         Unknown 2022-10-04 2022-10-04
# 197  284341                 Hugo Michon         Unknown 2021-12-20 2021-12-20
#
#                                           program  overallScore  \
# 0    Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# 2    Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# 3    Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# 4                          Cybersecurity Bootcamp           5.0
# 5    Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# ..                                            ...           ...
# 100                       Cybersecurity Part-Time           4.0
# 125                       Cyber Security Bootcamp           5.0
# 126                       Cyber Security Bootcamp           5.0
# 135                       Cybersecurity Part-Time           3.3
# 197                       Cyber Security Bootcamp           5.0
#
#                                               comments overall  curriculum  \
# 0    [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 2    [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 3    [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 4    [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 5    [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# ..                                                 ...     ...         ...
# 100                                                 []     5.0         3.0
# 125                                                 []     5.0         5.0
# 126                                                 []     5.0         5.0
# 135                                                 []     3.0         3.0
# 197                                                 []     5.0         5.0
#
#      jobSupport                                        review_body  \
# 0           5.0  I'm so glad I found the Evolve Security Academ...
# 2           5.0  The Evolve Academy bootcamp is a good entry fo...
# 3           5.0  I recently transitioned from graphic design to...
# 4           5.0  After thorough bootcamp research, I confidentl...
# 5           5.0  I really enjoyed the ESCP Cybersecurity Bootca...
# ..          ...                                                ...
# 100         4.0  My favorite part of this BootCamp was how ever...
# 125         5.0  Participating on this bootcamp was an amazing ...
# 126         5.0  I was looking forward for a career change, in ...
# 135         4.0  Pros: Good environment, good facilitators that...
# 197         5.0  I did a full time remote bootcamp for cybersec...
#
#                       school  bootcamp_id
# 0    evolve-security-academy        10743
# 2    evolve-security-academy        10743
# 3    evolve-security-academy        10743
# 4    evolve-security-academy        10743
# 5    evolve-security-academy        10743
# ..                       ...          ...
# 100                 ironhack        10828
# 125                 ironhack        10828
# 126                 ironhack        10828
# 135                 ironhack        10828
# 197                 ironhack        10828
#
# [248 rows x 14 columns]

# %%
comments['createdAt'] = pd.to_datetime(comments['createdAt'])

# Remove hours, minutes, and seconds from 'Date Updated' that appears on MySQL
comments['createdAt'] = comments['createdAt'].dt.date
comments
# Out:
#           id                   name hostProgramName   createdAt  queryDate  \
# 0     310012      Yolanda Mondragon         Unknown  2024-04-10 2024-04-10
# 1     309927      MINH CUONG NGUYEN         Unknown  2024-04-06 2024-04-06
# 2     308332             Michelle H         Unknown  2024-01-31 2024-01-31
# 3     308033    Sandrine Mamigonian         Unknown  2024-01-18 2024-01-18
# 4     307829            kacy yancey         Unknown  2024-01-09 2024-01-09
# ...      ...                    ...             ...         ...        ...
# 1288  231772              Anonymous         Unknown  2014-09-30 2014-09-30
# 1289  231636        Marcos Sorribas         Unknown  2014-09-24 2014-09-24
# 1290  231611          Xabier Vicuña         Unknown  2014-09-24 2014-09-24
# 1291  231609                    JHD         Unknown  2014-09-24 2014-09-24
# 1292  231815  Enrique Isasi Velasco    UX/UI Design  2014-09-23 2014-09-23
#
#                                            program  overallScore  \
# 0     Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# 1                                          Unknown           4.0
# 2     Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# 3     Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# 4                           Cybersecurity Bootcamp           5.0
# ...                                            ...           ...
# 1288                     Part-time Web Development           5.0
# 1289           Full-time Web Development Bootcamp            5.0
# 1290                     Part-time Web Development           5.0
# 1291                     Part-time Web Development           5.0
# 1292                     Part-time Web Development           5.0
#
#                                                comments overall  curriculum  \
# 0     [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 1     [{'name': 'Colleen', 'email': 'cbradley@evolve...     4.0         4.0
# 2     [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 3     [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 4     [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# ...                                                 ...     ...         ...
# 1288                                                 []     5.0         5.0
# 1289                                                 []     5.0         5.0
# 1290                                                 []     5.0         5.0
# 1291                                                 []     5.0         5.0
# 1292                                                 []     5.0         5.0
#
#       jobSupport                                        review_body  \
# 0            5.0  I'm so glad I found the Evolve Security Academ...
# 1            4.0  Pros: The course was amazing, it created a sol...
# 2            5.0  The Evolve Academy bootcamp is a good entry fo...
# 3            5.0  I recently transitioned from graphic design to...
# 4            5.0  After thorough bootcamp research, I confidentl...
# ...          ...                                                ...
# 1288         5.0  I can fully recommend IronHack for any of you ...
# 1289         5.0  Asistí al primer bootcamp de desarrollo de iOS...
# 1290         5.0  Excellent product. Great experience. Worth eve...
# 1291         5.0  I was part of the first English run of Ironhac...
# 1292         5.0  I attended the Ironhack Madrid Bootcamp on Jan...
#
#                        school  bootcamp_id
# 0     evolve-security-academy        10743
# 1     evolve-security-academy        10743
# 2     evolve-security-academy        10743
# 3     evolve-security-academy        10743
# 4     evolve-security-academy        10743
# ...                       ...          ...
# 1288                 ironhack        10828
# 1289                 ironhack        10828
# 1290                 ironhack        10828
# 1291                 ironhack        10828
# 1292                 ironhack        10828
#
# [4532 rows x 14 columns]

# %%
comments['queryDate'] = pd.to_datetime(comments['queryDate'])

# Remove hours, minutes, and seconds from 'Date Updated' that appears on MySQL
comments['queryDate'] = comments['queryDate'].dt.date
comments
# Out:
#           id                   name hostProgramName   createdAt   queryDate  \
# 0     310012      Yolanda Mondragon         Unknown  2024-04-10  2024-04-10
# 1     309927      MINH CUONG NGUYEN         Unknown  2024-04-06  2024-04-06
# 2     308332             Michelle H         Unknown  2024-01-31  2024-01-31
# 3     308033    Sandrine Mamigonian         Unknown  2024-01-18  2024-01-18
# 4     307829            kacy yancey         Unknown  2024-01-09  2024-01-09
# ...      ...                    ...             ...         ...         ...
# 1288  231772              Anonymous         Unknown  2014-09-30  2014-09-30
# 1289  231636        Marcos Sorribas         Unknown  2014-09-24  2014-09-24
# 1290  231611          Xabier Vicuña         Unknown  2014-09-24  2014-09-24
# 1291  231609                    JHD         Unknown  2014-09-24  2014-09-24
# 1292  231815  Enrique Isasi Velasco    UX/UI Design  2014-09-23  2014-09-23
#
#                                            program  overallScore  \
# 0     Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# 1                                          Unknown           4.0
# 2     Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# 3     Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# 4                           Cybersecurity Bootcamp           5.0
# ...                                            ...           ...
# 1288                     Part-time Web Development           5.0
# 1289           Full-time Web Development Bootcamp            5.0
# 1290                     Part-time Web Development           5.0
# 1291                     Part-time Web Development           5.0
# 1292                     Part-time Web Development           5.0
#
#                                                comments overall  curriculum  \
# 0     [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 1     [{'name': 'Colleen', 'email': 'cbradley@evolve...     4.0         4.0
# 2     [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 3     [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 4     [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# ...                                                 ...     ...         ...
# 1288                                                 []     5.0         5.0
# 1289                                                 []     5.0         5.0
# 1290                                                 []     5.0         5.0
# 1291                                                 []     5.0         5.0
# 1292                                                 []     5.0         5.0
#
#       jobSupport                                        review_body  \
# 0            5.0  I'm so glad I found the Evolve Security Academ...
# 1            4.0  Pros: The course was amazing, it created a sol...
# 2            5.0  The Evolve Academy bootcamp is a good entry fo...
# 3            5.0  I recently transitioned from graphic design to...
# 4            5.0  After thorough bootcamp research, I confidentl...
# ...          ...                                                ...
# 1288         5.0  I can fully recommend IronHack for any of you ...
# 1289         5.0  Asistí al primer bootcamp de desarrollo de iOS...
# 1290         5.0  Excellent product. Great experience. Worth eve...
# 1291         5.0  I was part of the first English run of Ironhac...
# 1292         5.0  I attended the Ironhack Madrid Bootcamp on Jan...
#
#                        school  bootcamp_id
# 0     evolve-security-academy        10743
# 1     evolve-security-academy        10743
# 2     evolve-security-academy        10743
# 3     evolve-security-academy        10743
# 4     evolve-security-academy        10743
# ...                       ...          ...
# 1288                 ironhack        10828
# 1289                 ironhack        10828
# 1290                 ironhack        10828
# 1291                 ironhack        10828
# 1292                 ironhack        10828
#
# [4532 rows x 14 columns]

# %% [markdown]
# ## Ironhack Reviews

# %%
# Print unique reviews from 'comments' column for ironhack
unique_reviews = cyber_security_comments['review_body'].unique()
print("Unique reviews for Ironhack:")
for review in unique_reviews:
    print(review)
# Out:
# Unique reviews for Ironhack:
# I'm so glad I found the Evolve Security Academy Cybersecurity Program because it would have been near impossible for me to curate all the course content, exercises, quizzes, labs, etc. on my own (despite the vast availability of free resources, this simply... Read More is a very hard thing to do). The format (live online lectures, coupled with some recorded lectures and work you do on your time) was very effective! You don’t miss out on class and instructor interactions, and, at the same time, you get through much of the material on your own time. Class meetings were M-Th evenings for 2 hours—that made it easier to do than a longer stretch of 3 hours. Office hours were held every evening we had class, so you get the best opportunity to ask questions and stay abreast of the material. The Saturday classes were every other week for 5 hours, which allowed time for assessments, extended exercises, and labs. The curriculum was laid out in a logical sense, with additional resources given if you want to learn/practice even more. Having quizzes, many labs, and assessments kept us in line with the material. The best part of the program: the instructors and teaching assistants (T.A.s) -- knowledgeable professionals, fully available and helpful to a 'T'. Even though I loved all the instructors, I would say this program would not be the same without the close assistance of the T.A.s! I'd highly recommend the ESA bootcamp because it's a professional program and very well executed, with a huge amount of learning opportunities, and it prepares someone for an entry-level job in cybersecurity. The support in terms of instructors, TAs, the director, our career coach, the CyberLab learning portal, etc. is truly outstanding!Read Less
entimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# Define function to categorize sentiment
def categorize_sentiment(review):
    scores = sid.polarity_scores(review)
    compound_score = scores['compound']
    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Apply sentiment analysis and categorization to review_body
filtered_comments['sentiment'] = filtered_comments['review_body'].apply(categorize_sentiment)

# Count sentiment categories for each school
sentiment_counts = filtered_comments.groupby(['school', 'sentiment']).size().unstack(fill_value=0)

# Plotting
plt.figure(figsize=(10, 6))
sentiment_counts.plot(kind='bar', stacked=True, color=['#FFD700', '#00008B', 'grey'])  # Dark Yellow, Dark Blue, Grey
plt.title('Sentiment Analysis of Cyber Security Comments')
plt.xlabel('School')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=0)
plt.legend(title='Sentiment')
plt.show()
# Out:
# /var/folders/k5/l8tkch0x0538653kdhf3q9p00000gn/T/ipykernel_43504/3539152490.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_comments['sentiment'] = filtered_comments['review_body'].apply(categorize_sentiment)

# %%
# Function to check if review contains "cons"
def contains_cons(review):
    return re.search(r'\bCons\b', review, flags=re.IGNORECASE) is not None

# Filter rows where review contains "cons"
cons_reviews = cyber_security_comments[cyber_security_comments['review_body'].apply(contains_cons)]

# Print the rows with "cons"
print(cons_reviews['review_body'].tolist())
# Out:
# ['Pros: -The bootcamp gave me a trajectory to follow in terms of where to look for knowledge. -I was given hands on experience with multiple tools used in the field. -I was able to make connections in the cyber field. -I was able to become very good friends... Read More with my group and collaborate on projects outside of school. -The bootcamp gives a voucher for the CompTIA security+ exam. Cons: -Constantly going through lead instructors. -The lead instructor when I left taught nothing and relied on the assistant instructors to teach. -I believe the cohort is incredibly overpriced for what you get. -I was lucky to get an AI who was not condescending, not every group gets one.Read Less', "I joined this boot camp because I wanted more hands-on lab experience, accountability, and networking with others. This bootcamp was also more affordable than a Master's degree (I have a Bachelor's in Sociology, but wanted to get into Cybersecurity).... Read More When comparing the course content between this bootcamp and a Master's degree, I found that this bootcamp had more practical learning, and not just lecturing you like a traditional class setting. If you're someone who also has these desires, this may be the place for you! Pros: - Non-competitive learning environment where you can work together - Friendly and understanding instructors, always there to help and quick replies - Instructors always want to improve the bootcamp and accept criticism - Encourages you to push out of your comfort zone to enable success (for this bootcamp and also for job preparation) - Lots of opportunity for hands on labs - Creating life long friends - Friends/classmates will motivate you to do TryHackMe boxes and other certifications to build your resume - Great job prepping material (Linkedin setup, tailored-resume, etc.) Mediating Factors: - You have to put in the effort to get the most out of the bootcamp - You have to study and take really good notes - You have to redo some of the labs if you want to understand it better - You have to ask for help if you need help Cons: - Sometimes there's issues with the virtual box or website, but they're usually solved very quickly and won't hold you accountable for mistakes on their end - The face-paced environment could be a con for some people who have a really busy schedule or work better in a slower paced environment. There were times where I felt it went by really fast, and where I personally thought I might not succeed and I thought I was the only one that felt this way- but when I did study sessions outside of class time with other students, they felt the same way. So don't feel discouraged. I learned to take away the big picture, take good notes, continously review, and study smarter. I was able to complete the bootcamp, and so can you! Focus more on topics you really enjoy and want to do in the future. - Sometimes the Zoom recordings don't get uploaded as fast as I want them to. It could be very difficult to catch up if you miss class. If you don't have access immediately, always reach out to classmates to catch up on missed-material. Overall, I am very satisfied with what I got out of this bootcamp. I think this was one of the best decisions that I have made, and will always support Evolve Security! I highly recommend this bootcamp for anyone wanting to be in the Cybersecurity field. Overall, I am very satisified with what I have accomplished in this bootcamp!Read Less", "Pros: knowledgeable instructors, well planned material Cons: a bit intense and time consuming Overall this was a great program. The course material was well planned and the instructors and fellow students were all eager for everyone to succeed without... Read More just giving us the answers. Emphasis on teaching not just the answers, but how to find the answers they don't teach.Read Less", "I'll start with pros as they are more prominent than the cons. Evolve Security Academy does a great job and it was definitely worth it. I got plenty of ...

# %%
#Count how many review_body entries exist and how many of these are not anonymous 
# Filter reviews for dates after 2019
filtered_comments = cyber_security_comments[
    (cyber_security_comments['createdAt'] > '2019-12-31') & 
    (cyber_security_comments['school'] == 'ironhack')]

# Count total reviews
total_reviews = filtered_comments['review_body'].count()

# Count non-anonymous reviews
non_anonymous_reviews = filtered_comments[filtered_comments['name'] != 'Anonymous']['review_body'].count()

# Print the results
print(f'Total reviews after 2019: {total_reviews}')
print(f'Non-anonymous reviews after 2019: {non_anonymous_reviews}')
# Out:
# Total reviews after 2019: 9
# Non-anonymous reviews after 2019: 5

# %% [markdown]
# # Overall Score for Cyber Security program

# %%
#Overall Score by school
scores_by_school=cyber_security_comments.groupby('school').agg({'overallScore': 'mean'})
scores_by_school.sort_values(by='overallScore', ascending=True).reset_index()

# %%
#Overall Score by school considering different cyber security programs
scores_by_program=cyber_security_comments.groupby(['school','program']).agg({'overallScore': 'mean'})
scores_by_program.sort_values(by='overallScore', ascending=True).reset_index()

# %%
cyber_security_comments.dtypes

# %%
#Check Nulls Before doing Correlation Matrix
# Check how many rows have missing values in 'overallScore', 'curriculum', and 'job support'
missing_overallScore = cyber_security_comments['overallScore'].isnull().sum()
missing_curriculum = cyber_security_comments['curriculum'].isnull().sum()
missing_job_support = cyber_security_comments['jobSupport'].isnull().sum()

print(f"Rows with missing 'overallScore': {missing_overallScore}")
print(f"Rows with missing 'curriculum': {missing_curriculum}")
print(f"Rows with missing 'job support': {missing_job_support}")

# %%
# Group by school and calculate the mean
mean_scores = cyber_security_comments.groupby('school')[['overallScore', 'curriculum', 'jobSupport']].mean()

# Create a correlation matrix for each school
correlation_matrices = {}

for school in mean_scores.index:
    school_data = cyber_security_comments[cyber_security_comments['school'] == school][['overallScore', 'curriculum', 'jobSupport']]
    correlation_matrix = school_data.corr()
    correlation_matrices[school] = correlation_matrix

# Create a DataFrame to store all correlation matrices in a tabular format
correlation_table = pd.DataFrame()

for school, correlation_matrix in correlation_matrices.items():
    # Flatten the correlation matrix
    flat_correlation = correlation_matrix.stack().reset_index()
    flat_correlation.columns = ['Variable1', 'Variable2', 'Correlation']
    flat_correlation['School'] = school
    
    # Append to the correlation table
    correlation_table = pd.concat([correlation_table, flat_correlation], ignore_index=True)

# Filter for rows where Variable1 is 'overallScore' and Variable2 is not 'overallScore'
overallScore_correlation = correlation_table[(correlation_table['Variable1'] == 'overallScore') & (correlation_table['Variable2'] != 'overallScore')]

display(overallScore_correlation)
# Out:
#        Variable1   Variable2  Correlation  \
# 1   overallScore  curriculum     1.000000
# 5   overallScore  curriculum     1.000000
# 6   overallScore  jobSupport     1.000000
# 14  overallScore  curriculum     0.449089
# 15  overallScore  jobSupport     0.860678
# 23  overallScore  curriculum     0.898692
# 24  overallScore  jobSupport     0.890873
# 32  overallScore  curriculum     0.920890
# 33  overallScore  jobSupport     0.971714
# 41  overallScore  curriculum     0.821570
# 42  overallScore  jobSupport     0.790587
# 50  overallScore  curriculum     0.869895
# 51  overallScore  jobSupport     0.940899
#
#                                                School
# 1                                           clarusway
# 5   colorado-state-university-pueblo-extended-studies
# 6   colorado-state-university-pueblo-extended-studies
# 14                                            edureka
# 15                                            edureka
# 23                            evolve-security-academy
# 24                            evolve-security-academy
# 32                                           ironhack
# 33                                           ironhack
# 41                                        simplilearn
# 42                                        simplilearn
# 50                                        springboard
# 51                                        springboard

# %%
mean_scores
# Out:
#                                                    overallScore  curriculum  \
# school
# clarusway                                              4.976923    4.923077
# colorado-state-university-pueblo-extended-studies      4.375000    4.375000
# edureka                                                4.480000    4.800000
# evolve-security-academy                                4.820000    4.894737
# ironhack                                               4.144444    4.111111
# simplilearn                                            4.560606    4.666667
# springboard                                            4.625455    4.600000
# syntax-technologies                                    5.000000    5.000000
#
#                                                    jobSupport
# school
# clarusway                                            5.000000
# colorado-state-university-pueblo-extended-studies    4.285714
# edureka                                              3.800000
# evolve-security-academy                              4.673684
# ironhack                                             4.222222
# simplilearn                                          4.266667
# springboard                                          4.545455
# syntax-technologies                                  5.000000

# %%
# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a figure and a set of subplots
plt.figure(figsize=(14, 6))

# Scatter plot for overallScore vs. curriculum
plt.subplot(1, 2, 1)
sns.regplot(x='curriculum', y='overallScore', data=mean_scores, scatter_kws={'s': 50}, line_kws={'color': 'blue'})
plt.title('Overall Score vs Curriculum Score')
plt.xlabel('Curriculum Score')
plt.ylabel('Overall Score')

# Scatter plot for overallScore vs. jobSupport
plt.subplot(1, 2, 2)
sns.regplot(x='jobSupport', y='overallScore', data=mean_scores, scatter_kws={'s': 50}, line_kws={'color': 'red'})
plt.title('Overall Score vs Job Support Score')
plt.xlabel('Job Support Score')
plt.ylabel('Overall Score')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
ß
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[341], line 26
#      24 # Show the plot
#      25 plt.show()
# ---> 26 ß
#
# NameError: name 'ß' is not defined

# %% [markdown]
# # What could influence the scores that people give?

# %% [markdown]
# ### Does Ironhack have a good score curriculum and job support?

# %%
ironhack_scores = mean_scores.loc['ironhack']

# Print the mean of curriculum and jobSupport for Ironhack
print("Mean scores for Ironhack")
print("Curriculum:", ironhack_scores['curriculum'])
print("Job Support:", ironhack_scores['jobSupport'])

# %% [markdown]
# ### Compare the reviews for full time and part time

# %%
scores_by_program.loc['ironhack']

# %% [markdown]
# # Other Tables
# ### Location, badges, school list

# %%
from pandas import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    price_min = data['content']['priceMin']
    price_max = data['content']['priceMax']
    prices_df = pd.DataFrame([[price_min, price_max]], columns=['priceMin', 'priceMax'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    prices_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id
    prices_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df, prices_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []
prices_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d,e = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
    prices_list.append(e)
# Out:
# evolve-security-academy
# syntax-technologies
# level-effect
# clarusway
# simplilearn
# springboard
# edureka
# colorado-state-university-pueblo-extended-studies
# ironhack

# %% [markdown]
# ## Spread of Ironhack Around the World

# %%
locations = pd.concat(locations_list)
locations
# Out:
#       id                 description  state.id state.name state.abbrev  \
# 0  15899                      Online       1.0     Online       Online
# 1  16045  Chicago, IL, United States      15.0   Illinois           IL
# 0  18261                      Online       1.0     Online       Online
# 0  17374                      Online       1.0     Online       Online
# 0  17789                      Online       1.0     Online       Online
# 0  17099                      Online       1.0     Online       Online
# 0  16013                      Online       1.0     Online       Online
# 0  18115                      Online       1.0     Online       Online
# 0  17416                      Online       1.0     Online       Online
# 0  15901             Berlin, Germany       NaN        NaN          NaN
# 1  16022         Mexico City, Mexico       NaN        NaN          NaN
# 2  16086      Amsterdam, Netherlands       NaN        NaN          NaN
# 3  16088           Sao Paulo, Brazil       NaN        NaN          NaN
# 4  16109               Paris, France       NaN        NaN          NaN
# 5  16375    Miami, FL, United States      11.0    Florida           FL
# 6  16376               Madrid, Spain       NaN        NaN          NaN
# 7  16377            Barcelona, Spain       NaN        NaN          NaN
# 8  16709            Lisbon, Portugal       NaN        NaN          NaN
# 9  17233                      Online       1.0     Online       Online
#
#   state.keyword  country.id   country.name country.abbrev  city.id  \
# 0        online         NaN            NaN            NaN      NaN
# 1      illinois         1.0  United States             US     39.0
# 0        online         NaN            NaN            NaN      NaN
# 0        online         NaN            NaN            NaN      NaN
# 0        online         NaN            NaN            NaN      NaN
# 0        online         NaN            NaN            NaN      NaN
# 0        online         NaN            NaN            NaN      NaN
# 0        online         NaN            NaN            NaN      NaN
# 0        online         NaN            NaN            NaN      NaN
# 0           NaN        57.0        Germany             DE  31156.0
# 1           NaN        29.0         Mexico             MX  31175.0
# 2           NaN        59.0    Netherlands             NL  31168.0
# 3           NaN        42.0         Brazil             BR  31121.0
# 4           NaN        38.0         France             FR  31136.0
# 5       florida         1.0  United States             US     31.0
# 6           NaN        12.0          Spain             ES  31052.0
# 7           NaN        12.0          Spain             ES  31170.0
# 8           NaN        28.0       Portugal             PT  31075.0
# 9        online         NaN            NaN            NaN      NaN
#
#      city.name city.keyword  \
# 0          NaN          NaN
# 1      Chicago      chicago
# 0          NaN          NaN
# 0          NaN          NaN
# 0          NaN          NaN
# 0          NaN          NaN
# 0          NaN          NaN
# 0          NaN          NaN
# 0          NaN          NaN
# 0       Berlin       berlin
# 1  Mexico City  mexico-city
# 2    Amsterdam    amsterdam
# 3    Sao Paulo    sao-paulo
# 4        Paris        paris
# 5        Miami        miami
# 6       Madrid       madrid
# 7    Barcelona    barcelona
# 8       Lisbon       lisbon
# 9          NaN          NaN
#
#                                               school  school_id
# 0                            evolve-security-academy      10743
# 1                            evolve-security-academy      10743
# 0                                syntax-technologies      11797
# 0                                       level-effect      11282
# 0                                          clarusway      11539
# 0                                        simplilearn      11016
# 0                                        springboard      11035
# 0                                            edureka      11739
# 0  colorado-state-university-pueblo-extended-studies      11296
# 0                                           ironhack      10828
# 1                                           ironhack      10828
# 2                                           ironhack      10828
# 3                                           ironhack      10828
# 4                                           ironhack      10828
# 5                                           ironhack      10828
# 6                                           ironhack      10828
# 7                                           ironhack      10828
# 8                                           ironhack      10828
# 9                                           ironhack      10828

# %%
# Replace NaN values with 'Unknown'
locations.fillna('Unknown', inplace=True)

display(locations)
# Out:
# /var/folders/k5/l8tkch0x0538653kdhf3q9p00000gn/T/ipykernel_43504/1506847398.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   locations.fillna('Unknown', inplace=True)
#       id                 description state.id state.name state.abbrev  \
# 0  15899                      Online      1.0     Online       Online
# 1  16045  Chicago, IL, United States     15.0   Illinois           IL
# 0  18261                      Online      1.0     Online       Online
# 0  17374                      Online      1.0     Online       Online
# 0  17789                      Online      1.0     Online       Online
# 0  17099                      Online      1.0     Online       Online
# 0  16013                      Online      1.0     Online       Online
# 0  18115                      Online      1.0     Online       Online
# 0  17416                      Online      1.0     Online       Online
# 0  15901             Berlin, Germany  Unknown    Unknown      Unknown
# 1  16022         Mexico City, Mexico  Unknown    Unknown      Unknown
# 2  16086      Amsterdam, Netherlands  Unknown    Unknown      Unknown
# 3  16088           Sao Paulo, Brazil  Unknown    Unknown      Unknown
# 4  16109               Paris, France  Unknown    Unknown      Unknown
# 5  16375    Miami, FL, United States     11.0    Florida           FL
# 6  16376               Madrid, Spain  Unknown    Unknown      Unknown
# 7  16377            Barcelona, Spain  Unknown    Unknown      Unknown
# 8  16709            Lisbon, Portugal  Unknown    Unknown      Unknown
# 9  17233                      Online      1.0     Online       Online
#
#   state.keyword country.id   country.name country.abbrev  city.id  \
# 0        online    Unknown        Unknown        Unknown  Unknown
# 1      illinois        1.0  United States             US     39.0
# 0        online    Unknown        Unknown        Unknown  Unknown
# 0        online    Unknown        Unknown        Unknown  Unknown
# 0        online    Unknown        Unknown        Unknown  Unknown
# 0        online    Unknown        Unknown        Unknown  Unknown
# 0        online    Unknown        Unknown        Unknown  Unknown
# 0        online    Unknown        Unknown        Unknown  Unknown
# 0        online    Unknown        Unknown        Unknown  Unknown
# 0       Unknown       57.0        Germany             DE  31156.0
# 1       Unknown       29.0         Mexico             MX  31175.0
# 2       Unknown       59.0    Netherlands             NL  31168.0
# 3       Unknown       42.0         Brazil             BR  31121.0
# 4       Unknown       38.0         France             FR  31136.0
# 5       florida        1.0  United States             US     31.0
# 6       Unknown       12.0          Spain             ES  31052.0
# 7       Unknown       12.0          Spain             ES  31170.0
# 8       Unknown       28.0       Portugal             PT  31075.0
# 9        online    Unknown        Unknown        Unknown  Unknown
#
#      city.name city.keyword  \
# 0      Unknown      Unknown
# 1      Chicago      chicago
# 0      Unknown      Unknown
# 0      Unknown      Unknown
# 0      Unknown      Unknown
# 0      Unknown      Unknown
# 0      Unknown      Unknown
# 0      Unknown      Unknown
# 0      Unknown      Unknown
# 0       Berlin       berlin
# 1  Mexico City  mexico-city
# 2    Amsterdam    amsterdam
# 3    Sao Paulo    sao-paulo
# 4        Paris        paris
# 5        Miami        miami
# 6       Madrid       madrid
# 7    Barcelona    barcelona
# 8       Lisbon       lisbon
# 9      Unknown      Unknown
#
#                                               school  school_id
# 0                            evolve-security-academy      10743
# 1                            evolve-security-academy      10743
# 0                                syntax-technologies      11797
# 0                                       level-effect      11282
# 0                                          clarusway      11539
# 0                                        simplilearn      11016
# 0                                        springboard      11035
# 0                                            edureka      11739
# 0  colorado-state-university-pueblo-extended-studies      11296
# 0                                           ironhack      10828
# 1                                           ironhack      10828
# 2                                           ironhack      10828
# 3                                           ironhack      10828
# 4                                           ironhack      10828
# 5                                           ironhack      10828
# 6                                           ironhack      10828
# 7                                           ironhack      10828
# 8                                           ironhack      10828
# 9                                           ironhack      10828

# %%
# Columns to remove
columns_to_remove = ['state.abbrev', 'state.keyword', 'country.abbrev', 'city.keyword']

# Remove the specified columns
locations = locations.drop(columns=columns_to_remove)

display(locations)
# Out:
#       id                 description state.id state.name country.id  \
# 0  15899                      Online      1.0     Online    Unknown
# 1  16045  Chicago, IL, United States     15.0   Illinois        1.0
# 0  18261                      Online      1.0     Online    Unknown
# 0  17374                      Online      1.0     Online    Unknown
# 0  17789                      Online      1.0     Online    Unknown
# 0  17099                      Online      1.0     Online    Unknown
# 0  16013                      Online      1.0     Online    Unknown
# 0  18115                      Online      1.0     Online    Unknown
# 0  17416                      Online      1.0     Online    Unknown
# 0  15901             Berlin, Germany  Unknown    Unknown       57.0
# 1  16022         Mexico City, Mexico  Unknown    Unknown       29.0
# 2  16086      Amsterdam, Netherlands  Unknown    Unknown       59.0
# 3  16088           Sao Paulo, Brazil  Unknown    Unknown       42.0
# 4  16109               Paris, France  Unknown    Unknown       38.0
# 5  16375    Miami, FL, United States     11.0    Florida        1.0
# 6  16376               Madrid, Spain  Unknown    Unknown       12.0
# 7  16377            Barcelona, Spain  Unknown    Unknown       12.0
# 8  16709            Lisbon, Portugal  Unknown    Unknown       28.0
# 9  17233                      Online      1.0     Online    Unknown
#
#     country.name  city.id    city.name  \
# 0        Unknown  Unknown      Unknown
# 1  United States     39.0      Chicago
# 0        Unknown  Unknown      Unknown
# 0        Unknown  Unknown      Unknown
# 0        Unknown  Unknown      Unknown
# 0        Unknown  Unknown      Unknown
# 0        Unknown  Unknown      Unknown
# 0        Unknown  Unknown      Unknown
# 0        Unknown  Unknown      Unknown
# 0        Germany  31156.0       Berlin
# 1         Mexico  31175.0  Mexico City
# 2    Netherlands  31168.0    Amsterdam
# 3         Brazil  31121.0    Sao Paulo
# 4         France  31136.0        Paris
# 5  United States     31.0        Miami
# 6          Spain  31052.0       Madrid
# 7          Spain  31170.0    Barcelona
# 8       Portugal  31075.0       Lisbon
# 9        Unknown  Unknown      Unknown
#
#                                               school  school_id
# 0                            evolve-security-academy      10743
# 1                            evolve-security-academy      10743
# 0                                syntax-technologies      11797
# 0                                       level-effect      11282
# 0                                          clarusway      11539
# 0                                        simplilearn      11016
# 0                                        springboard      11035
# 0                                            edureka      11739
# 0  colorado-state-university-pueblo-extended-studies      11296
# 0                                           ironhack      10828
# 1                                           ironhack      10828
# 2                                           ironhack      10828
# 3                                           ironhack      10828
# 4                                           ironhack      10828
# 5                                           ironhack      10828
# 6                                           ironhack      10828
# 7                                           ironhack      10828
# 8                                           ironhack      10828
# 9                                           ironhack      10828

# %%
# Replace '.' to '_' in all columns to make queries work on SQL
locations.rename(columns={'country.name': 'country_name','state.id': 'state_id', 'state.name': 'state_name','country.id': 'country_id', 'city.id': 'city_id','city.name': 'city_name' }, inplace=True)
locations
# Out:
#       id                 description state_id state_name country_id  \
# 0  15899                      Online      1.0     Online    Unknown
# 1  16045  Chicago, IL, United States     15.0   Illinois        1.0
# 0  18261                      Online      1.0     Online    Unknown
# 0  17374                      Online      1.0     Online    Unknown
# 0  17789                      Online      1.0     Online    Unknown
# 0  17099                      Online      1.0     Online    Unknown
# 0  16013                      Online      1.0     Online    Unknown
# 0  18115                      Online      1.0     Online    Unknown
# 0  17416                      Online      1.0     Online    Unknown
# 0  15901             Berlin, Germany  Unknown    Unknown       57.0
# 1  16022         Mexico City, Mexico  Unknown    Unknown       29.0
# 2  16086      Amsterdam, Netherlands  Unknown    Unknown       59.0
# 3  16088           Sao Paulo, Brazil  Unknown    Unknown       42.0
# 4  16109               Paris, France  Unknown    Unknown       38.0
# 5  16375    Miami, FL, United States     11.0    Florida        1.0
# 6  16376               Madrid, Spain  Unknown    Unknown       12.0
# 7  16377            Barcelona, Spain  Unknown    Unknown       12.0
# 8  16709            Lisbon, Portugal  Unknown    Unknown       28.0
# 9  17233                      Online      1.0     Online    Unknown
#
#     country_name  city_id    city_name  \
# 0        Unknown  Unknown      Unknown
# 1  United States     39.0      Chicago
# 0        Unknown  Unknown      Unknown
# 0        Unknown  Unknown      Unknown
# 0        Unknown  Unknown      Unknown
# 0        Unknown  Unknown      Unknown
# 0        Unknown  Unknown      Unknown
# 0        Unknown  Unknown      Unknown
# 0        Unknown  Unknown      Unknown
# 0        Germany  31156.0       Berlin
# 1         Mexico  31175.0  Mexico City
# 2    Netherlands  31168.0    Amsterdam
# 3         Brazil  31121.0    Sao Paulo
# 4         France  31136.0        Paris
# 5  United States     31.0        Miami
# 6          Spain  31052.0       Madrid
# 7          Spain  31170.0    Barcelona
# 8       Portugal  31075.0       Lisbon
# 9        Unknown  Unknown      Unknown
#
#                                               school  school_id
# 0                            evolve-security-academy      10743
# 1                            evolve-security-academy      10743
# 0                                syntax-technologies      11797
# 0                                       level-effect      11282
# 0                                          clarusway      11539
# 0                                        simplilearn      11016
# 0                                        springboard      11035
# 0                                            edureka      11739
# 0  colorado-state-university-pueblo-extended-studies      11296
# 0                                           ironhack      10828
# 1                                           ironhack      10828
# 2                                           ironhack      10828
# 3                                           ironhack      10828
# 4                                           ironhack      10828
# 5                                           ironhack      10828
# 6                                           ironhack      10828
# 7                                           ironhack      10828
# 8                                           ironhack      10828
# 9                                           ironhack      10828

# %%
# Filter rows where school is 'ironhack'
filtered_df = locations[locations['school'] == 'ironhack']

# Group by 'description', 'id', and 'country_name'
grouped_df = filtered_df.groupby(['city_name', 'id', 'country_name']).size().reset_index(name='counts')

print(grouped_df)
# Out:
#      city_name     id   country_name  counts
# 0    Amsterdam  16086    Netherlands       1
# 1    Barcelona  16377          Spain       1
# 2       Berlin  15901        Germany       1
# 3       Lisbon  16709       Portugal       1
# 4       Madrid  16376          Spain       1
# 5  Mexico City  16022         Mexico       1
# 6        Miami  16375  United States       1
# 7        Paris  16109         France       1
# 8    Sao Paulo  16088         Brazil       1
# 9      Unknown  17233        Unknown       1

# %%
import folium

# Sample DataFrame with city_name and some lat/lon data for mapping
location_data = {
    'city_name': ['Amsterdam', 'Barcelona', 'Berlin', 'Lisbon', 'Madrid', 
                  'Mexico City', 'Miami', 'Paris', 'Sao Paulo'],
    'latitude': [52.3676, 41.3851, 52.5200, 38.7223, 40.4168, 
                 19.4326, 25.7617, 48.8566, -23.5505],
    'longitude': [4.9041, 2.1734, 13.4050, -9.1393, -3.7038, 
                  -99.1332, -80.1918, 2.3522, -46.6333]
}

location_df = pd.DataFrame(location_data)

# Merge the grouped_df with location_df to get lat/lon
merged_df = pd.merge(grouped_df, location_df, on='city_name', how='left')

# Create a GeoDataFrame
gdf = gpd.GeoDataFrame(
    merged_df, geometry=gpd.points_from_xy(merged_df.longitude, merged_df.latitude))

# Create a Folium map
m = folium.Map(location=[20, 0], zoom_start=2)

# Add points to the map
for idx, row in gdf.iterrows():
    if pd.notna(row['latitude']) and pd.notna(row['longitude']):
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f"City: {row['city_name']}, Country: {row['country_name']}"
        ).add_to(m)
    else:
        print(f"Location data not found for city: {row['city_name']}")

# Save the map to an HTML file
m.save('map.html')

# Display the map in a Jupyter Notebook (optional)
m
# Out:
# Location data not found for city: Unknown
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68adfa40d85b1ca79d831dffb641d494 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68adfa40d85b1ca79d831dffb641d494&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68adfa40d85b1ca79d831dffb641d494 = L.map(
#                 &quot;map_68adfa40d85b1ca79d831dffb641d494&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_686d204dd2238b60f8ca1c472f674f51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_686d204dd2238b60f8ca1c472f674f51.addTo(map_68adfa40d85b1ca79d831dffb641d494);
#
#
#             var marker_bb0681a218cb379b9b4eb50a15b7ee94 = L.marker(
#                 [52.3676, 4.9041],
#                 {}
#             ).addTo(map_68adfa40d85b1ca79d831dffb641d494);
#
#
#         var popup_afab50d0fa3c7db3cbd8d34f85fecc8d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_880d7595dbcac3a3b3e8e6936da58ba5 = $(`&lt;div id=&quot;html_880d7595dbcac3a3b3e8e6936da58ba5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Amsterdam, Country: Netherlands&lt;/div&gt;`)[0];
#                 popup_afab50d0fa3c7db3cbd8d34f85fecc8d.setContent(html_880d7595dbcac3a3b3e8e6936da58ba5);
#
#
#
#         marker_bb0681a218cb379b9b4eb50a15b7ee94.bindPopup(popup_afab50d0fa3c7db3cbd8d34f85fecc8d)
#         ;
#
#
#
#
#             var marker_33693a2c9521e3f951978b63bb36468b = L.marker(
#                 [41.3851, 2.1734],
#                 {}
#             ).addTo(map_68adfa40d85b1ca79d831dffb641d494);
#
#
#         var popup_bdbdfd7f0946c2ce6e62ba8bb9360f15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18aa698f59b58db2c304dedd603cd709 = $(`&lt;div id=&quot;html_18aa698f59b58db2c304dedd603cd709&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Barcelona, Country: Spain&lt;/div&gt;`)[0];
#                 popup_bdbdfd7f0946c2ce6e62ba8bb9360f15.setContent(html_18aa698f59b58db2c304dedd603cd709);
#
#
#
#         marker_33693a2c9521e3f951978b63bb36468b.bindPopup(popup_bdbdfd7f0946c2ce6e62ba8bb9360f15)
#         ;
#
#
#
#
#             var marker_062d145db9acaab12671fa73e28fa5db = L.marker(
#                 [52.52, 13.405],
#                 {}
#             ).addTo(map_68adfa40d85b1ca79d831dffb641d494);
#
#
#         var popup_e3d644a6b4d3923789014ddb2e720fea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_35f46362842116c5a1d67fda743e32fb = $(`&lt;div id=&quot;html_35f46362842116c5a1d67fda743e32fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Berlin, Country: Germany&lt;/div&gt;`)[0];
#                 popup_e3d644a6b4d3923789014ddb2e720fea.setContent(html_35f46362842116c5a1d67fda743e32fb);
#
#
#
#         marker_062d145db9acaab12671fa73e28fa5db.bindPopup(popup_e3d644a6b4d3923789014ddb2e720fea)
#         ;
#
#
#
#
#             var marker_79c4130d644663142b1df9d21c29eab0 = L.marker(
#                 [38.7223, -9.1393],
#                 {}
#             ).addTo(map_68adfa40d85b1ca79d831dffb641d494);
#
#
#         var popup_f6872800174d63fd3b34d415ecae67e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56cb0d12e4264253b9dae750785e74f7 = $(`&lt;div id=&quot;html_56cb0d12e4264253b9dae750785e74f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Lisbon, Country: Portugal&lt;/div&gt;`)[0];
#                 popup_f6872800174d63fd3b34d415ecae67e1.setContent(html_56cb0d12e4264253b9dae750785e74f7);
#
#
#
#         marker_79c4130d644663142b1df9d21c29eab0.bindPopup(popup_f6872800174d63fd3b34d415ecae67e1)
#         ;
#
#
#
#
#             var marker_da921cd4b2b6d67157847e5e0e3310b7 = L.marker(
#                 [40.4168, -3.7038],
#                 {}
#             ).addTo(map_68adfa40d85b1ca79d831dffb641d494);
#
#
#         var popup_fe71b4297e21aa1cd0d4d02a45c5aa15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03fffe593a5fadda72e8fc820e4e837e = $(`&lt;div id=&quot;html_03fffe593a5fadda72e8fc820e4e837e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Madrid, Country: Spain&lt;/div&gt;`)[0];
#                 popup_fe71b4297e21aa1cd0d4d02a45c5aa15.setContent(html_03fffe593a5fadda72e8fc820e4e837e);
#
#
#
#         marker_da921cd4b2b6d67157847e5e0e3310b7.bindPopup(popup_fe71b4297e21aa1cd0d4d02a45c5aa15)
#         ;
#
#
#
#
#             var marker_d10af72963ddf6e0d0cae89e2b18af53 = L.marker(
#                 [19.4326, -99.1332],
#                 {}
#             )

# %% [markdown]
# ### Is Ironhack present in US?

# %%
ironhack_locations = locations[locations['school'] == 'ironhack']
ironhack_countries = ironhack_locations['country_name'].dropna().unique()
ironhack_countries = [country for country in ironhack_countries if country != 'Unknown']
print("Countries where Ironhack is present:")
print(ironhack_countries)
# Out:
# Countries where Ironhack is present:
# ['Germany', 'Mexico', 'Netherlands', 'Brazil', 'France', 'United States', 'Spain', 'Portugal']

# %% [markdown]
# ### Schools with online courses

# %%
online_schools = locations[locations['description'].str.contains('Online', case=False)]
online_school_list = online_schools['school'].unique()
print("Schools offering online courses:")
print(online_school_list)
# Out:
# Schools offering online courses:
# ['evolve-security-academy' 'syntax-technologies' 'level-effect'
#  'clarusway' 'simplilearn' 'springboard' 'edureka'
#  'colorado-state-university-pueblo-extended-studies' 'ironhack']

# %%
courses = pd.concat(courses_list)
courses.head(10)
# Out:
#                                              courses                   school  \
# 0       Cybersecurity Bootcamp: REMOTE (Live-Online)  evolve-security-academy
# 1                        OSCP Bootcamp (Live-Online)  evolve-security-academy
# 2                             Cybersecurity Bootcamp  evolve-security-academy
# 0                              Cyber Security Course      syntax-technologies
# 1      Data Analytics & Business Intelligence Course      syntax-technologies
# 2                     SDET Automation Testing Course      syntax-technologies
# 0                     Cyber Defense Analyst Bootcamp             level-effect
# 0                            AWS Solutions Architect                clarusway
# 1  AWS Solutions Architect - Premium Full Time/Pa...                clarusway
# 2            AWS Solutions Architect/DevOps Engineer                clarusway
#
#    school_id
# 0      10743
# 1      10743
# 2      10743
# 0      11797
# 1      11797
# 2      11797
# 0      11282
# 0      11539
# 1      11539
# 2      11539

# %%
badges = pd.concat(badges_list)
badges
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2    Accepts GI Bill    accepts_gi_bill
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
#
#                                          description  \
# 0          <p>School offers fully online courses</p>
# 1  <p>School offers part-time and evening classes...
# 0          <p>School offers fully online courses</p>
# 1  <p>School offers part-time and evening classes...
# 0          <p>School offers fully online courses</p>
# 1  <p>School offers part-time and evening classes...
# 0          <p>School offers fully online courses</p>
# 1  <p>School offers part-time and evening classes...
# 0          <p>School offers fully online courses</p>
# 1  <p>School offers part-time and evening classes...
# 0          <p>School offers fully online courses</p>
# 1  <p>School offers part-time and evening classes...
# 2             <p>School guarantees job placement</p>
# 0          <p>School offers fully online courses</p>
# 1  <p>School offers part-time and evening classes...
# 0          <p>School offers fully online courses</p>
# 1  <p>School offers part-time and evening classes...
# 2                  <p>School accepts the GI Bill</p>
# 0          <p>School offers fully online courses</p>
# 1  <p>School publishes a third-party verified out...
# 2  <p>School offers part-time and evening classes...
#
#                                               school  school_id
# 0                            evolve-security-academy      10743
# 1                            evolve-security-academy      10743
# 0                                syntax-technologies      11797
# 1                                syntax-technologies      11797
# 0                                       level-effect      11282
# 1                                       level-effect      11282
# 0                                          clarusway      11539
# 1                                          clarusway      11539
# 0                                        simplilearn      11016
# 1                                        simplilearn      11016
# 0                                        springboard      11035
# 1                                        springboard      11035
# 2                                        springboard      11035
# 0                                            edureka      11739
# 1                                            edureka      11739
# 0  colorado-state-university-pueblo-extended-studies      11296
# 1  colorado-state-university-pueblo-extended-studies      11296
# 2  colorado-state-university-pueblo-extended-studies      11296
# 0                                           ironhack      10828
# 1                                           ironhack      10828
# 2                                           ironhack      10828

# %%
# Remove <p> and </p> tags
badges['description'] = badges['description'].str.replace('<p>', '', regex=False)
badges['description'] = badges['description'].str.replace('</p>', '', regex=False)

display(badges)
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2    Accepts GI Bill    accepts_gi_bill
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
#
#                                          description  \
# 0                 School offers fully online courses
# 1        School offers part-time and evening classes
# 0                 School offers fully online courses
# 1        School offers part-time and evening classes
# 0                 School offers fully online courses
# 1        School offers part-time and evening classes
# 0                 School offers fully online courses
# 1        School offers part-time and evening classes
# 0                 School offers fully online courses
# 1        School offers part-time and evening classes
# 0                 School offers fully online courses
# 1        School offers part-time and evening classes
# 2                    School guarantees job placement
# 0                 School offers fully online courses
# 1        School offers part-time and evening classes
# 0                 School offers fully online courses
# 1        School offers part-time and evening classes
# 2                         School accepts the GI Bill
# 0                 School offers fully online courses
# 1  School publishes a third-party verified outcom...
# 2        School offers part-time and evening classes
#
#                                               school  school_id
# 0                            evolve-security-academy      10743
# 1                            evolve-security-academy      10743
# 0                                syntax-technologies      11797
# 1                                syntax-technologies      11797
# 0                                       level-effect      11282
# 1                                       level-effect      11282
# 0                                          clarusway      11539
# 1                                          clarusway      11539
# 0                                        simplilearn      11016
# 1                                        simplilearn      11016
# 0                                        springboard      11035
# 1                                        springboard      11035
# 2                                        springboard      11035
# 0                                            edureka      11739
# 1                                            edureka      11739
# 0  colorado-state-university-pueblo-extended-studies      11296
# 1  colorado-state-university-pueblo-extended-studies      11296
# 2  colorado-state-university-pueblo-extended-studies      11296
# 0                                           ironhack      10828
# 1                                           ironhack      10828
# 2                                           ironhack      10828

# %%
# Group by 'school' and count the number of badges (name)
badge_counts = badges.groupby('school')['name'].count().reset_index(name='badge_count')
badge_counts
# Out:
#                                               school  badge_count
# 0                                          clarusway            2
# 1  colorado-state-university-pueblo-extended-studies            3
# 2                                            edureka            2
# 3                            evolve-security-academy            2
# 4                                           ironhack            3
# 5                                       level-effect            2
# 6                                        simplilearn            2
# 7                                        springboard            3
# 8                                syntax-technologies            2

# %%
# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='badge_count', y='school', data=badge_counts, palette='Bluesß')
plt.xlabel('Number of Badges')
plt.ylabel('School')
plt.title('Number of Badges per School')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
#     405 else:
# --> 406     cmap = get_colormap(name)
#     408 if name in MPL_QUAL_PALS:
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/_compat.py:133, in get_colormap(name)
#     132 try:
# --> 133     return mpl.colormaps[name]
#     134 except AttributeError:
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/cm.py:88, in ColormapRegistry.__getitem__(self, item)
#      87 except KeyError:
# ---> 88     raise KeyError(f"{item!r} is not a known colormap name") from None
#
# KeyError: "'Bluesß' is not a known colormap name"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[355], line 3
#       1 # Plotting
#       2 plt.figure(figsize=(10, 6))
# ----> 3 sns.barplot(x='badge_count', y='school', data=badge_counts, palette='Bluesß')
#       4 plt.xlabel('Number of Badges')
#       5 plt.ylabel('School')
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:1532, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1529 """Initialize the plotter."""
#    1530 self.establish_variables(x, y, hue, data, orient,
#    1531                          order, hue_order, units)
# -> 1532 self.establish_colors(color, palette, saturation)
#    1533 self.estimate_statistic(estimator, errorbar, n_boot, seed)
#    1535 self.dodge = dodge
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:696, in _CategoricalPlotter.establish_colors(self, color, palette, saturation)
#     693             levels = self.hue_names
#     694         palette = [palette[l] for l in levels]
# --> 696     colors = color_palette(palette, n_colors)
#     698 # Desaturate a bit because these are patches
#     699 if saturation < 1:
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/palettes.py:237, in color_palette(palette, n_colors, desat, as_cmap)
#     235             palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236         except (ValueError, KeyError):  # Error class changed in mpl36
# --> 237             raise ValueError(f"{palette!r} is not a valid palette name")
#     239 if desat is not None:
#     240     palette = [desaturate(c, desat) for c in palette]
#
# ValueError: 'Bluesß' is not a valid palette name

# %%
# Filter badges for ironhack
ironhack_badges = badges[badges['school'] == 'ironhack']

# Get distinct descriptions for ironhack
ironhack_descriptions = ironhack_badges['name'].unique()

# Get all distinct descriptions
all_descriptions = badges['name'].unique()

# Find missing descriptions for ironhack
missing_descriptions = set(all_descriptions) - set(ironhack_descriptions)

# Provide descriptions for ironhack badges
print("Descriptions for ironhack badges:")
for description in ironhack_descriptions:
    print(description)

# Provide missing descriptions for ironhack
print("\nMissing descriptions for ironhack:")
for description in missing_descriptions:
    print(description)
# Out:
# Descriptions for ironhack badges:
# Available Online
# Verified Outcomes
# Flexible Classes
#
# Missing descriptions for ironhack:
# Accepts GI Bill
# Job Guarantee

# %%
# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)
schools.head()
# Out:
#                                              website  \
# 0  evolvesecurity.io/academy/home?utm_source=swit...
# 0                               www.syntaxtechs.com/
# 0                                   leveleffect.com/
# 0                                     clarusway.com/
# 0                                   simplilearn.com/
#
#                                          description  \
# 0  <span class="truncatable"><p>Evolve Security A...
# 0  <span class="truncatable"><p>Syntax Technologi...
# 0  <span class="truncatable"><p>Level Effect is a...
# 0  <span class="truncatable"><p>Clarusway is a hi...
# 0  <span class="truncatable"><p>Simplilearn is th...
#
#                                              LogoUrl                   school  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  evolve-security-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...      syntax-technologies
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             level-effect
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...                clarusway
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...              simplilearn
#
#    school_id
# 0      10743
# 0      11797
# 0      11282
# 0      11539
# 0      11016

# %%
# Define the regex pattern to remove the HTML tags
html = r'<span class="truncatable"><p>|</p></span>'

# Apply the str.replace method to the 'description' column
schools['description'] = schools['description'].str.replace(html, '', regex=True)

# %%
schools
# Out:
#                                              website  \
# 0  evolvesecurity.io/academy/home?utm_source=swit...
# 0                               www.syntaxtechs.com/
# 0                                   leveleffect.com/
# 0                                     clarusway.com/
# 0                                   simplilearn.com/
# 0  www.springboard.com/?utm_source=switchup&utm_m...
# 0                                    www.edureka.co/
# 0                          csupueblo.quickstart.com/
# 0                                www.ironhack.com/en
#
#                                          description  \
# 0  Evolve Security Academy offers holistic cybers...
# 0  Syntax Technologies is the world’s leading onl...
# 0  Level Effect is a premier training provider of...
# 0  Clarusway is a highly respected IT training sc...
# 0  Simplilearn is the world's #1 online Bootcamp ...
# 0  Springboard is an online learning platform tha...
# 0  Edureka is one of the world's leading online B...
# 0  QuickStart, an online IT certification courses...
# 0  Ironhack is a global tech school with 9 campus...
#
#                                              LogoUrl  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...
#
#                                               school  school_id
# 0                            evolve-security-academy      10743
# 0                                syntax-technologies      11797
# 0                                       level-effect      11282
# 0                                          clarusway      11539
# 0                                        simplilearn      11016
# 0                                        springboard      11035
# 0                                            edureka      11739
# 0  colorado-state-university-pueblo-extended-studies      11296
# 0                                           ironhack      10828

# %%
prices = pd.concat(prices_list)
prices
# Out:
#   priceMin priceMax                                             school  \
# 0     5250    13950                            evolve-security-academy
# 0     None     None                                syntax-technologies
# 0    11000    11000                                       level-effect
# 0      750    21500                                          clarusway
# 0        0     8000                                        simplilearn
# 0      349     9900                                        springboard
# 0      399     3775                                            edureka
# 0     5400     7400  colorado-state-university-pueblo-extended-studies
# 0     7500    13000                                           ironhack
#
#    school_id
# 0      10743
# 0      11797
# 0      11282
# 0      11539
# 0      11016
# 0      11035
# 0      11739
# 0      11296
# 0      10828

# %%
# Replace None values with 'Unknown'
prices.fillna('Unknown', inplace=True)

display(prices)
# Out:
#   priceMin priceMax                                             school  \
# 0     5250    13950                            evolve-security-academy
# 0  Unknown  Unknown                                syntax-technologies
# 0    11000    11000                                       level-effect
# 0      750    21500                                          clarusway
# 0        0     8000                                        simplilearn
# 0      349     9900                                        springboard
# 0      399     3775                                            edureka
# 0     5400     7400  colorado-state-university-pueblo-extended-studies
# 0     7500    13000                                           ironhack
#
#    school_id
# 0      10743
# 0      11797
# 0      11282
# 0      11539
# 0      11016
# 0      11035
# 0      11739
# 0      11296
# 0      10828

# %% [markdown]
# # Python to MySQL

# %%
saved_pass = getpass.getpass()
# Out:
#  ········

# %%
cnx = mysql.connector.connect(
    user = 'root',
    password = saved_pass,
    database= 'bootcamps',
    port=3306)

# Confirm that we stabilish a connection
if cnx.is_connected():
    print('Your connection was successfull')
else:
    print('Connection unsuccessfull')
# Out:
# Your connection was successfull

# %%
# Create a cursor
cursor = cnx.cursor()

# %%
# Create a new database
query = ("""CREATE DATABASE IF NOT EXISTS bootcamps""")
cursor.execute(query)

# %%
# Create an SQLAlchemy engine using the MySQL connection details
engine = create_engine(f'mysql+mysqlconnector://root:{saved_pass}@localhost/bootcamps')

# %%
# Insert the DataFrame into a table named 'all_bootcamps'
all_bootcamp_data.to_sql(name='all_bootcamps', con=engine, if_exists='replace', index=False)
# Out:
# 54

# %%
comments.dtypes
# Out:
# id                   Int64
# name                object
# hostProgramName     object
# createdAt           object
# queryDate           object
# program             object
# overallScore       float64
# comments            object
# overall             object
# curriculum         float64
# jobSupport         float64
# review_body         object
# school              object
# bootcamp_id          int64
# dtype: object

# %%
# Check for null values
null_counts = comments.isnull().sum()
print("Null values in each column:\n", null_counts)
# Out:
# Null values in each column:
#  id                   0
# name                 0
# hostProgramName      0
# createdAt            0
# queryDate            0
# program              0
# overallScore         5
# comments             0
# overall              0
# curriculum          40
# jobSupport         301
# review_body          0
# school               0
# bootcamp_id          0
# dtype: int64

# %%
comments['hostProgramName'].fillna('Unknown', inplace=True)
comments['program'].fillna('Unknown', inplace=True)
comments['overallScore'].fillna(0, inplace=True)
comments['overall'].fillna(0, inplace=True)
comments['curriculum'].fillna(0, inplace=True)
comments['jobSupport'].fillna(0, inplace=True)

# %%
comments.rename(columns={"bootcamp_id": "school_id"})
# Out:
#           id                   name hostProgramName   createdAt   queryDate  \
# 0     310012      Yolanda Mondragon         Unknown  2024-04-10  2024-04-10
# 1     309927      MINH CUONG NGUYEN         Unknown  2024-04-06  2024-04-06
# 2     308332             Michelle H         Unknown  2024-01-31  2024-01-31
# 3     308033    Sandrine Mamigonian         Unknown  2024-01-18  2024-01-18
# 4     307829            kacy yancey         Unknown  2024-01-09  2024-01-09
# ...      ...                    ...             ...         ...         ...
# 1288  231772              Anonymous         Unknown  2014-09-30  2014-09-30
# 1289  231636        Marcos Sorribas         Unknown  2014-09-24  2014-09-24
# 1290  231611          Xabier Vicuña         Unknown  2014-09-24  2014-09-24
# 1291  231609                    JHD         Unknown  2014-09-24  2014-09-24
# 1292  231815  Enrique Isasi Velasco    UX/UI Design  2014-09-23  2014-09-23
#
#                                            program  overallScore  \
# 0     Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# 1                                          Unknown           4.0
# 2     Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# 3     Cybersecurity Bootcamp: REMOTE (Live-Online)           5.0
# 4                           Cybersecurity Bootcamp           5.0
# ...                                            ...           ...
# 1288                     Part-time Web Development           5.0
# 1289           Full-time Web Development Bootcamp            5.0
# 1290                     Part-time Web Development           5.0
# 1291                     Part-time Web Development           5.0
# 1292                     Part-time Web Development           5.0
#
#                                                comments overall  curriculum  \
# 0     [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 1     [{'name': 'Colleen', 'email': 'cbradley@evolve...     4.0         4.0
# 2     [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 3     [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# 4     [{'name': 'Colleen', 'email': 'cbradley@evolve...     5.0         5.0
# ...                                                 ...     ...         ...
# 1288                                                 []     5.0         5.0
# 1289                                                 []     5.0         5.0
# 1290                                                 []     5.0         5.0
# 1291                                                 []     5.0         5.0
# 1292                                                 []     5.0         5.0
#
#       jobSupport                                        review_body  \
# 0            5.0  I'm so glad I found the Evolve Security Academ...
# 1            4.0  Pros: The course was amazing, it created a sol...
# 2            5.0  The Evolve Academy bootcamp is a good entry fo...
# 3            5.0  I recently transitioned from graphic design to...
# 4            5.0  After thorough bootcamp research, I confidentl...
# ...          ...                                                ...
# 1288         5.0  I can fully recommend IronHack for any of you ...
# 1289         5.0  Asistí al primer bootcamp de desarrollo de iOS...
# 1290         5.0  Excellent product. Great experience. Worth eve...
# 1291         5.0  I was part of the first English run of Ironhac...
# 1292         5.0  I attended the Ironhack Madrid Bootcamp on Jan...
#
#                        school  school_id
# 0     evolve-security-academy      10743
# 1     evolve-security-academy      10743
# 2     evolve-security-academy      10743
# 3     evolve-security-academy      10743
# 4     evolve-security-academy      10743
# ...                       ...        ...
# 1288                 ironhack      10828
# 1289                 ironhack      10828
# 1290                 ironhack      10828
# 1291                 ironhack      10828
# 1292                 ironhack      10828
#
# [4532 rows x 14 columns]

# %%
comments.to_sql(name='reviews', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:919, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     918 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 919     cursor.executemany(statement, parameters)
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/cursor_cext.py:496, in CMySQLCursor.executemany(self, operation, seq_params)
#     495     return None
# --> 496 stmt = self._batch_insert(operation, seq_params)
#     497 if stmt is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/cursor_cext.py:450, in CMySQLCursor._batch_insert(self, operation, seq_params)
#     449 except Exception as err:
# --> 450     raise InterfaceError(f"Failed executing the operation; {err}") from None
#
# InterfaceError: Failed executing the operation; Python type list cannot be converted
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# Cell In[372], line 1
# ----> 1 comments.to_sql(name='reviews', con=engine, if_exists='replace', index=False)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
#    (...)
#    3004 [(1,), (None,), (2,)]
#    3005 """  # noqa: E501
#    3006 from pandas.io import sql
# -> 3008 return sql.to_sql(
#    3009     self,
#    3010     name,
#    3011     con,
#    3012     schema=schema,
#    3013     if_exists=if_exists,
#    3014     index=index,
#    3015     index_label=index_label,
#    3016     chunksize=chunksize,
#    3017     dtype=dtype,
#    3018     method=method,
#    3019 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:788, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     783     raise NotImplementedError(
#     784         "'frame' argument should be either a Series or a DataFrame"
#     785     )
#     787 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 788     return pandas_sql.to_sql(
#     789         frame,
#     790         name,
#     791         if_exists=if_exists,
#     792         index=index,
#     793         index_label=index_label,
#     794         schema=schema,
#     795         chunksize=chunksize,
#     796         dtype=dtype,
#     797         method=method,
#     798         engine=engine,
#     799         **engine_kwargs,
#     800     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1958, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1946 sql_engine = get_engine(engine)
#    1948 table = self.prep_table(
#    1949     frame=frame,
#    1950     name=name,
#    (...)
#    1955     dtype=dtype,
#    1956 )
# -> 1958 total_inserted = sql_engine.insert_records(
#    1959     table=table,
#    1960     con=self.con,
#    1961     frame=frame,
#    1962     name=name,
#    1963     index=index,
#    1964     schema=schema,
#    1965     chunksize=chunksize,
#    1966     method=method,
#    1967     **engine_kwargs,
#    1968 )
#    1970 self.check_case_sensitive(name=name, schema=schema)
#    1971 return total_inserted
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1507, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1505 if re.search(msg, err_text):
#    1506     raise ValueError("inf cannot be used with MySQL") from err
# -> 1507 raise err
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1498, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1495 from sqlalchemy import exc
#    1497 try:
# -> 1498     return table.insert(chunksize=chunksize, method=method)
#    1499 except exc.StatementError as err:
#    1500     # GH34431
#    1501     # https://stackoverflow.com/a/67358288/6067848
#    1502     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1503     )|inf can not be used with MySQL"""
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1059, in SQLTable.insert(self, chunksize, method)
#    1056     break
#    1058 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1059 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1060 # GH 46891
#    1061 if num_inserted is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:951, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     939 """
#     940 Execute SQL statement inserting data
#     941
#    (...)
#     948    Each item contains a list of values to be inserted
#     949 """
#     950 data = [dict(zip(keys, row)) for row in data_iter]
# --> 951 result = conn.execute(self.table.insert(), data)
#     952 return result.rowcount
#
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:517, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     515     if TYPE_CHECKING:
#     516         assert isinstance(self, Executable)
# --> 517     return connection._execute_clauseelement(
#     518         self, distilled_params, execution_options
#     519     )
#     520 else:
#     521     raise exc.ObjectNotExecutableError(self)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2342 elif should_wrap:
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#    2346     assert exc_info[1] is not None
#
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1936                 break
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#    1945     if self.dialect._has_events:
#
# File /opt/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:919, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     918 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 919     cursor.executemany(statement, parameters)
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/cursor_cext.py:496, in CMySQLCursor.executemany(self, operation, seq_params)
#     494     self._rowcount = 0
#     495     return None
# --> 496 stmt = self._batch_insert(operation, seq_params)
#     497 if stmt is not None:
#     498     self._executed = stmt
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/cursor_cext.py:450, in CMySQLCursor._batch_insert(self, operation, seq_params)
#     448     raise ProgrammingError(str(err)) from err
#     449 except Exception as err:
# --> 450     raise InterfaceError(f"Failed executing the operation; {err}") from None
#
# InterfaceError: (mysql.connector.errors.InterfaceError) Failed executing the operation; Python type list cannot be converted
# [SQL: INSERT INTO reviews (id, name, `hostProgramName`, `createdAt`, `queryDate`, program, `overallScore`, comments, overall, curriculum, `jobSupport`, review_body, school, bootcamp_id) VALUES (%(id)s, %(name)s, %(hostProgramName)s, %(createdAt)s, %(queryDate)s, %(program)s, %(overallScore)s, %(comments)s, %(overall)s, %(curriculum)s, %(jobSupport)s, %(review_body)s, %(school)s, %(bootcamp_id)s)]
# [parameters: [{'id': 310012, 'name': 'Yolanda Mondragon', 'hostProgramName': 'Unknown', 'createdAt': datetime.date(2024, 4, 10), 'queryDate': datetime.date(2024, 4, 10), 'program': 'Cybersecurity Bootcamp: REMOTE (Live-Online)', 'overallScore': 5.0, 'comments': [{'name': 'Colleen', 'email': 'cbradley@evolvesecurity.com', 'body': '<span class="truncatable"><p>Thank you for sharing your experience, Yolanda! It\ ... (523 characters truncated) ... span></p><span class=\'read-less-text\' style=\'display:none;\'><a class=\'read-less-button\'>Read Less</a></span></span>', 'createdAt': '4/23/2024'}], 'overall': '5.0', 'curriculum': 5.0, 'jobSupport': 5.0, 'review_body': "I'm so glad I found the Evolve Security Academy Cybersecurity Program because it would have been near impossible for me to curate all the course cont ... (1444 characters truncated) ... security. The support in terms of instructors, TAs, the director, our career coach, the CyberLab learning portal, etc. is truly outstanding!Read Less", 'school': 'evolve-security-academy', 'bootcamp_id': 10743}, {'id': 309927, 'name': 'MINH CUONG NGUYEN', 'hostProgramName': 'Unknown', 'createdAt': datetime.date(2024, 4, 6), 'queryDate': datetime.date(2024, 4, 6), 'program': 'Unknown', 'overallScore': 4.0, 'comments': [{'name': 'Colleen', 'email': 'cbradley@evolvesecurity.com', 'body': '<span class="truncatable"><p>Congratulations on achieving your OSCP certificatio ... (430 characters truncated) ... span></p><span class=\'read-less-text\' style=\'display:none;\'><a class=\'read-less-button\'>Read Less</a></span></span>', 'createdAt': '4/23/2024'}], 'overall': '4.0', 'curriculum': 4.0, 'jobSupport': 4.0, 'review_body': "Pros: The course was amazing, it created a solid push for me to obtain the OSCP certification. I've acquired new and valuable skills and techniques,  ... (719 characters truncated) ... proved, especially, the search function. I couldn't search for the machine name at the time I did the course. Overall, I'd give a solid 4/5.Read Less", 'school': 'evolve-security-academy', 'bootcamp_id': 10743}, {'id': 308332, 'name': 'Michelle H', 'hostProgramName': 'Unknown', 'createdAt': datetime.date(2024, 1, 31), 'queryDate': datetime.date(2024, 1, 31), 'program': 'Cybersecurity Bootcamp: REMOTE (Live-Online)', 'overallScore': 5.0, 'comments': [{'name': 'Colleen', 'email': 'cbradley@evolvesecurity.com', 'body': '<span class="truncatable"><p>Thank you for your review, Michelle! We\'re thrille ... (630 characters truncated) ... /span></p><span class=\'read-less-text\' style=\'display:none;\'><a class=\'read-less-button\'>Read Less</a></span></span>', 'createdAt': '3/7/2024'}], 'overall': '5.0', 'curriculum': 5.0, 'jobSupport': 5.0, 'review_body': 'The Evolve Academy bootcamp is a good entry for anyone completely new to tech and looking for a career start in cybersecurity. Having different instr ... (178 characters truncated) ... hing and always eager to help. The small lab sections allowed every student to ask questions and really dig deep into any misunderstandings.Read Less', 'school': 'evolve-security-academy', 'bootcamp_id': 10743}, {'id': 308033, 'name': 'Sandrine Mamigonian', 'hostProgramName': 'Unknown', 'createdAt': datetime.date(2024, 1, 18), 'queryDate': datetime.date(2024, 1, 18), 'program': 'Cybersecurity Bootcamp: REMOTE (Live-Online)', 'overallScore': 5.0, 'comments': [{'name': 'Colleen', 'email': 'cbradley@evolvesecurity.com', 'body': '<span class="truncatable"><p>We\'re thrilled you successfully transitioned from  ... (559 characters truncated) ... /span></p><span class=\'read-less-text\' style=\'display:none;\'><a class=\'read-less-button\'>Read Less</a></span></span>', 'createdAt': '3/7/2024'}], 'overall': '5.0', 'curriculum': 5.0, 'jobSupport': 5.0, 'review_body': "I recently transitioned from graphic design to cyber security, and I'm grateful for Evolve Academy's support. Despite no prior IT knowledge, the tran ... (578 characters truncated) ... ity course. This inve ...
# (Background on this error at: https://sqlalche.me/e/20/rvf5)

# %%
locations.to_sql(name='locations', con=engine, if_exists='replace', index=False)
# Out:
# 19

# %%
badges.to_sql(name='badges', con=engine, if_exists='replace', index=False)
# Out:
# 21

# %%
schools.to_sql(name='schools_description', con=engine, if_exists='replace', index=False)
# Out:
# 9

# %%
prices.to_sql(name='prices', con=engine, if_exists='replace', index=False)
# Out:
# 9
